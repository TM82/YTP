# %%
import json
import requests
from collections import defaultdict

# %%
row_data = open('mayfes/json_data/todai_kyuka.json', 'r')

# %%
data = json.load(row_data)

# %%
len(data)
# Out:
# 300

# %%
type(data)
# Out:
# list

# %%
type(data[0])
# Out:
# dict

# %%
data[0].keys()
# Out:
# dict_keys(['title', 'texts'])

# %%
titles = []
texts = []
for dic in data:
    titles.extend(dic['title'])
    texts.extend(dic['texts'])

# %%
len(titles), len(texts)
# Out:
# (491, 1227)

# %%
import re
# from nltk import word_tokenize
# from nltk import WordNetLemmatizer
# from nltk.util import ngrams
from collections import Counter
import MeCab

ptn = re.compile("^[0-9]+$")
# lemmatizer = WordNetLemmatizer()

# %%
def load_stop(): #停止語類
    s = []
    f = open('stop.txt', 'r', encoding='utf8')
    lines = f.readlines()
    for l in lines:
        tmp = l.replace('\n', '') # 改行文字がある場合用
        s.append(tmp)
    f.close()
    return s

# stopwords = load_stop()

# %%
txt_dic = {} #キー:テキスト本文 値:単語
counter_list = []  #一テキストの単語のCounterが要素として入る。

for text in texts:
    #単語に区切る http://testpy.hatenablog.com/entry/2016/10/04/010000
    tagger = MeCab.Tagger("-Owakati")        
    result = tagger.parse(text)
    tokens = result.split()

    clean_tokens = [w for w in tokens if len(w)>1]

#     #単語の内、停止語類になく、一文字ではなく、数字のみではないものをclean_tokensに入れる
#     clean_tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stopwords and len(w)>1  and ptn.match(w) is None]

    #txt_dicにキーをテキスト本文、値をclean_tokensにして入れる(使用しないが動作確認用)
    txt_dic[text]= clean_tokens

    #一テキストごとのCounterを要素とするリストcounter_listに追加する。最終的にこの中身を足せばよい。
    counter_list.append(Counter(clean_tokens))

# %%
#counterを足しあわせる https://qiita.com/hatchinee/items/a904c1f8d732a4686c9d
all_word_counter = Counter()
for counter in counter_list:
    all_word_counter += counter

# %%
#頻度の高い上100個の単語を抽出
frequent_words = []
for counter in all_word_counter.most_common(100):
    frequent_words.append(counter[0])

# %%
all_word_counter.most_common()[:10]
# Out:
# [('...', 254),
#  ('ます', 197),
#  ('休業', 177),
#  ('する', 172),
#  ('00', 161),
#  ('情報', 145),
#  ('時間', 141),
#  ('平成', 138),
#  ('勤務', 120),
#  ('研究', 118)]

# %%
#各辞書は単語をキーに、頻度と種類のタプルを保持
noun_dic = defaultdict(int)
verb_dic = defaultdict(int)
adjective_dic = defaultdict(int)
adverb_dic = defaultdict(int)

for text in texts:
    #単語に区切る http://testpy.hatenablog.com/entry/2016/10/04/010000
    tagger = MeCab.Tagger("-Ochasen")        
    result = tagger.parseToNode(text)
    while result:
        try:
            word = result.surface
            if len(word) > 1:
                word_type = result.feature.split(',')[0]
                if word_type == "名詞":
                    noun_dic[word] += 1
                elif word_type == "動詞":
                    verb_dic[word] += 1
                elif word_type == "形容詞":
                    adjective_dic[word] += 1
                elif word_type == "副詞":
                    adverb_dic[word] += 1
                else:
                    pass
        except:
            pass

        result = result.next

#     clean_tokens = [w for w in tokens if len(w)>1]

#     #単語の内、停止語類になく、一文字ではなく、数字のみではないものをclean_tokensに入れる
#     clean_tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stopwords and len(w)>1  and ptn.match(w) is None]

    #txt_dicにキーをテキスト本文、値をclean_tokensにして入れる(使用しないが動作確認用)
#     txt_dic[text]= clean_tokens

    #一テキストごとのCounterを要素とするリストcounter_listに追加する。最終的にこの中身を足せばよい。
#     counter_list.append(Counter(clean_tokens))

# %%
with open('mayfes/text_data/todai_kyuka_noun.txt','w') as f:
    for k, v in sorted(noun_dic.items(), key=lambda x:x[1], reverse=True):
#         print("({0} , {1})".format(k, v)) # ==> 5 1, 2 3, 1 4の順番．valueで昇順の並び
        f.write("({0} , {1})\n".format(k, v))
# Out:
# (... , 239)
# (休業 , 164)
# (00 , 159)
# (情報 , 131)
# (時間 , 127)
# (平成 , 122)
# (研究 , 103)
# (勤務 , 96)
# (場合 , 91)
# (30 , 89)
# (保険 , 87)
# (期間 , 81)
# (手当 , 80)
# (). , 78)
# (こと , 74)
# (大学 , 74)
# (教育 , 73)
# (採用 , 72)
# (）. , 68)
# (休日 , 67)
# (年度 , 66)
# (育児 , 65)
# (求人 , 65)
# (学部 , 62)
# (11 , 62)
# (10 , 58)
# (2018 , 58)
# (教職員 , 57)
# (制度 , 57)
# (有給 , 54)
# (03 , 50)
# (授業 , 48)
# (介護 , 46)
# (12 , 46)
# (祝日 , 46)
# (20 , 46)
# (規則 , 45)
# (３月 , 44)
# (夏季 , 44)
# (17 , 44)
# (業務 , 42)
# (雇用 , 41)
# (2017 , 41)
# (掲載 , 40)
# (ため , 39)
# (厚生 , 39)
# (事務 , 37)
# (改正 , 36)
# (職員 , 36)
# (東京 , 36)
# (社会 , 35)
# (学生 , 35)
# (特別 , 35)
# (お知らせ , 35)
# (その他 , 35)
# (営業 , 35)
# (大学院 , 34)
# (18 , 34)
# (平日 , 34)
# (15 , 33)
# (経験 , 33)
# (支援 , 32)
# (19 , 32)
# (労働 , 31)
# (企業 , 31)
# (PDF , 30)
# (13 , 30)
# (閉店 , 30)
# (試験 , 29)
# (研修 , 29)
# (資格 , 29)
# (規定 , 28)
# (給与 , 28)
# (04 , 28)
# (募集 , 28)
# (14 , 27)
# (29 , 27)
# (年末年始 , 27)
# (転職 , 27)
# (以下 , 26)
# (相談 , 26)
# (紹介 , 26)
# (日本 , 26)
# (退職 , 25)
# (看護 , 25)
# (全国 , 25)
# (会長 , 25)
# (取得 , 24)
# (短縮 , 24)
# (学校 , 24)
# (予定 , 24)
# (キャンパス , 23)
# (年次 , 23)
# (福利 , 23)
# (教授 , 23)
# (土曜 , 22)
# (一斉 , 22)
# (支給 , 22)
# (年金 , 22)
# (健康 , 22)
# (駒場 , 22)
# (21 , 22)
# (法人 , 22)
# (28 , 21)
# (活動 , 21)
# (学年 , 21)
# (利用 , 21)
# (科学 , 21)
# (応募 , 21)
# (株式会社 , 21)
# (25 , 20)
# (更新 , 20)
# (就職 , 20)
# (目的 , 19)
# (履修 , 19)
# (各種 , 19)
# (内容 , 19)
# (産後 , 19)
# (実績 , 19)
# (施設 , 19)
# (本郷 , 19)
# (31 , 19)
# (日程 , 19)
# (可能 , 19)
# (技術 , 19)
# (2019 , 19)
# (課程 , 18)
# (組合 , 18)
# (日間 , 18)
# (16 , 18)
# (ライフ , 18)
# (FAX , 18)
# (文京 , 18)
# (公募 , 18)
# (活躍 , 18)
# (手続き , 17)
# (終了 , 17)
# (就業 , 17)
# (規程 , 17)
# (サイト , 17)
# (科目 , 17)
# (病院 , 17)
# (22 , 17)
# (食堂 , 17)
# (事項 , 16)
# (24 , 16)
# (検索 , 16)
# (教員 , 16)
# (窓口 , 16)
# (年生 , 16)
# (発信 , 16)
# (27 , 16)
# (教務 , 16)
# (対策 , 16)
# (学科 , 16)
# (専門 , 16)
# (国立 , 16)
# (教職 , 16)
# (希望 , 15)
# (入学 , 15)
# (26 , 15)
# (連携 , 15)
# (長期 , 15)
# (), , 15)
# (仕事 , 15)
# (管理 , 15)
# (）; , 15)
# (よう , 15)
# (賞与 , 15)
# (ターム , 15)
# (センター , 15)
# (チェック , 15)
# (人数 , 15)
# (予約 , 15)
# (さん , 15)
# (保存 , 15)
# (すべて , 15)
# (徒歩 , 15)
# (システム , 14)
# (詳細 , 14)
# (任期 , 14)
# (対応 , 14)
# (附属 , 14)
# (連合 , 14)
# (提供 , 14)
# (結婚 , 14)
# (筑波大学 , 14)
# (ツール , 14)
# (選考 , 14)
# (プログラム , 13)
# (出産 , 13)
# (契約 , 13)
# (申請 , 13)
# (労災 , 13)
# (000 , 13)
# (お願い , 13)
# (ページ , 13)
# (受付 , 13)
# (以上 , 13)
# (07 , 13)
# (交通 , 13)
# (英語 , 13)
# (休職 , 13)
# (キャリタス , 13)
# (OK , 13)
# (休憩 , 12)
# (対象 , 12)
# (登録 , 12)
# (23 , 12)
# (案内 , 12)
# (国際 , 12)
# (両立 , 12)
# (必要 , 12)
# (）～ , 12)
# (事業 , 12)
# (店舗 , 12)
# (子育て , 12)
# (休止 , 12)
# (演習 , 12)
# (年間 , 12)
# (jp , 12)
# (]. , 12)
# (重要 , 12)
# (社員 , 12)
# (環境 , 12)
# (住宅 , 12)
# ()、 , 12)
# (形式 , 12)
# (ファイル , 12)
# (出勤 , 11)
# (実施 , 11)
# (昇給 , 11)
# (保育 , 11)
# (日数 , 11)
# (共済 , 11)
# (サポート , 11)
# (世界 , 11)
# (セメスター , 11)
# (実践 , 11)
# (総合 , 11)
# (カレンダー , 11)
# (通勤 , 11)
# (首都 , 11)
# (就活 , 11)
# (千葉大学 , 11)
# (関係 , 10)
# (基準 , 10)
# (準備 , 10)
# (進学 , 10)
# (教養 , 10)
# (短時間 , 10)
# (条件 , 10)
# (もの , 10)
# (９月 , 10)
# (TEL , 10)
# (電子 , 10)
# (図書館 , 10)
# (記念 , 10)
# (確認 , 10)
# (午後 , 10)
# (下記 , 10)
# (改修 , 10)
# (４月 , 10)
# (加入 , 10)
# (実習 , 10)
# (購買 , 10)
# (40 , 10)
# (ワーク , 10)
# (世帯 , 10)
# (書店 , 10)
# (該当 , 9)
# (ところ , 9)
# (養育 , 9)
# (問い合わせ , 9)
# (在学 , 9)
# (0 , 9)
# (有期 , 9)
# (担当 , 9)
# (単位 , 9)
# (専攻 , 9)
# (当該 , 9)
# (注意 , 9)
# (付与 , 9)
# (説明 , 9)
# (メールアドレス , 9)
# (チーム , 9)
# (慶弔 , 9)
# (書類 , 9)
# (オンライン , 9)
# (委員 , 9)
# (東北大学 , 9)
# (大阪大学 , 9)
# (時給 , 9)
# (早稲田大学 , 9)
# (職種 , 9)
# (校長 , 9)
# (スケジュール , 9)
# (本郷三丁目 , 9)
# (主婦 , 9)
# (ＯＫ , 9)
# (扶養 , 9)
# (勤続 , 9)
# (とおり , 8)
# ()～ , 8)
# (一般 , 8)
# (留学生 , 8)
# (生活 , 8)
# (体験 , 8)
# (とき , 8)
# (皆さん , 8)
# (週間 , 8)
# (８月 , 8)
# (有無 , 8)
# (金曜日 , 8)
# (理解 , 8)
# (これ , 8)
# (完備 , 8)
# (代替 , 8)
# (状況 , 8)
# (卒業 , 8)
# (p , 8)
# (理学部 , 8)
# (電力 , 8)
# (関連 , 8)
# (図書 , 8)
# (決定 , 8)
# (カフェ , 8)
# (土曜日 , 8)
# (現在 , 8)
# (向け , 8)
# (:// , 8)
# (病気 , 8)
# (新卒 , 8)
# (行事 , 8)
# (基本 , 8)
# (サービス , 8)
# (2013 , 8)
# (要項 , 8)
# (多様 , 8)
# (経済 , 8)
# (ダウンロード , 8)
# (結果 , 8)
# (アルバイト , 8)
# (土日 , 8)
# (電気 , 8)
# (女性 , 8)
# (公立 , 8)
# (ブランク , 8)
# (ok , 8)
# (スタッフ , 8)
# (最大 , 8)
# (シフト , 8)
# (変更 , 7)
# (家族 , 7)
# (成績 , 7)
# (学事 , 7)
# (本学 , 7)
# (政策 , 7)
# (形態 , 7)
# (ほか , 7)
# (方法 , 7)
# (子ども , 7)
# (書籍 , 7)
# (メール , 7)
# (提出 , 7)
# (無料 , 7)
# (取り扱い , 7)
# (見学 , 7)
# (休み , 7)
# (pdf , 7)
# (工事 , 7)
# (メニュー , 7)
# (中央 , 7)
# (講義 , 7)
# (Tokyo , 7)
# (113 , 7)
# (http , 7)
# (待遇 , 7)
# (学歴 , 7)
# (直接 , 7)
# (問題 , 7)
# (研究所 , 7)
# (機械 , 7)
# (by , 7)
# (開発 , 7)
# (医療 , 7)
# (月給 , 7)
# (面接 , 7)
# (所定 , 6)
# (法令 , 6)
# (法律 , 6)
# (制定 , 6)
# (UTAS , 6)
# (ガイダンス , 6)
# (定期 , 6)
# (休講 , 6)
# (月曜日 , 6)
# (アクセス , 6)
# (従事 , 6)
# (高度 , 6)
# (様々 , 6)
# (学内 , 6)
# (限定 , 6)
# (組織 , 6)
# (木曜日 , 6)
# (基礎 , 6)
# (国家 , 6)
# (精神 , 6)
# (内線 , 6)
# (入居 , 6)
# (）, , 6)
# (配布 , 6)
# (午前 , 6)
# (火曜日 , 6)
# (心理 , 6)
# (文化 , 6)
# (空間 , 6)
# (証明 , 6)
# (こちら , 6)
# (of , 6)
# (0033 , 6)
# (Hongo , 6)
# (学術 , 6)
# (05 , 6)
# (実験 , 6)
# (前期 , 6)
# (45 , 6)
# (基本給 , 6)
# (超過 , 6)
# (キャリア , 6)
# (入社 , 6)
# (運営 , 6)
# (2012 , 6)
# (3816 , 6)
# (医事 , 6)
# (考慮 , 6)
# (01 , 6)
# (評価 , 6)
# (夏期 , 6)
# (京都大学 , 6)
# (会社 , 6)
# (理工学部 , 6)
# (DJI , 6)
# (Japan , 6)
# (港南 , 6)
# (); , 6)
# (クイズ , 6)
# (quiz , 6)
# (la , 6)
# (県立 , 6)
# (高等 , 6)
# (口コミ , 6)
# (充実 , 6)
# (団体 , 6)
# (中央大学 , 6)
# (歓迎 , 6)
# (リスト , 6)
# (50 , 6)
# (いずれ , 5)
# (発表 , 5)
# (交流 , 5)
# (特徴 , 5)
# (博士 , 5)
# (機構 , 5)
# (工学 , 5)
# (推進 , 5)
# (一覧 , 5)
# (小学校 , 5)
# (ごと , 5)
# (場所 , 5)
# (以外 , 5)
# (文部 , 5)
# (宿泊 , 5)
# (ホームページ , 5)
# (3469 , 5)
# (１０月 , 5)
# (データ , 5)
# (電話 , 5)
# (展示 , 5)
# (振替 , 5)
# (理学 , 5)
# (生物 , 5)
# (ピーク , 5)
# (需要 , 5)
# (通常 , 5)
# (KB , 5)
# (入試 , 5)
# (gif , 5)
# (豊富 , 5)
# (不便 , 5)
# (協力 , 5)
# (国民 , 5)
# (整備 , 5)
# (過去 , 5)
# (千葉 , 5)
# (専任 , 5)
# (分野 , 5)
# (55 , 5)
# (時間割 , 5)
# (shop , 5)
# (程度 , 5)
# (協会 , 5)
# (主要 , 5)
# (修士 , 5)
# (夜勤 , 5)
# (商品 , 5)
# (連絡 , 5)
# (年収 , 5)
# (業界 , 5)
# (操作 , 5)
# (免許 , 5)
# (中心 , 5)
# (農学部 , 5)
# (使用 , 5)
# (全般 , 5)
# (配置 , 5)
# (職務 , 5)
# (履歴 , 5)
# (上限 , 5)
# (閲覧 , 5)
# (九州大学 , 5)
# (東京工業大学 , 5)
# (東京農工大学 , 5)
# (講師 , 5)
# (パート , 5)
# (地図 , 5)
# (：. , 5)
# (補助 , 5)
# (人事 , 5)
# (OB , 5)
# (タウン , 5)
# (観光 , 5)
# (静岡大学 , 5)
# (アブルボア , 5)
# (週休 , 5)
# (大阪 , 5)
# (経営 , 5)
# (北海道大学 , 5)
# (時点 , 5)
# (自分 , 5)
# (写真 , 5)
# (エントリー , 5)
# (課題 , 5)
# (慶應義塾 , 5)
# (主夫 , 5)
# (不問 , 5)
# (連続 , 5)
# (練習 , 5)
# (社宅 , 5)
# (学園 , 5)
# (工場 , 5)
# (Boeing , 5)
# (細則 , 4)
# (１２月 , 4)
# (総則 , 4)
# (定め , 4)
# (五月 , 4)
# (学期 , 4)
# (マップ , 4)
# (卒業生 , 4)
# (産学 , 4)
# (出向 , 4)
# (導入 , 4)
# (一環 , 4)
# (海外 , 4)
# (概要 , 4)
# (開始 , 4)
# (～. , 4)
# (後期 , 4)
# (産前 , 4)
# (配偶 , 4)
# (事由 , 4)
# (お子さん , 4)
# (状態 , 4)
# (指定 , 4)
# (通知 , 4)
# (別表 , 4)
# (特例 , 4)
# (専用 , 4)
# (保育園 , 4)
# (ルーム , 4)
# (実現 , 4)
# (試用 , 4)
# (計算 , 4)
# (調整 , 4)
# (初任 , 4)
# (義務 , 4)
# (公務員 , 4)
# (所在 , 4)
# (コーナー , 4)
# (最新 , 4)
# (多数 , 4)
# (奨学 , 4)
# (イベント , 4)
# (宿舎 , 4)
# (周年 , 4)
# (冬季 , 4)
# (論文 , 4)
# (影響 , 4)
# (補講 , 4)
# (水曜日 , 4)
# (節電 , 4)
# (削減 , 4)
# (正面 , 4)
# (玄関 , 4)
# (地下 , 4)
# (通用 , 4)
# (設定 , 4)
# ((F9 , 4)
# (創立 , 4)
# (カフェテリア , 4)
# (おかけ , 4)
# (日曜日 , 4)
# (臨時 , 4)
# (共同 , 4)
# (協議 , 4)
# (	 , 4)
# (プロジェクト , 4)
# (臨床 , 4)
# (コース , 4)
# (www , 4)
# (講演 , 4)
# (翌年 , 4)
# (38 , 4)
# (100 , 4)
# (HOME , 4)
# (分析 , 4)
# (修業 , 4)
# (年限 , 4)
# (財務 , 4)
# (６月 , 4)
# (能力 , 4)
# (医学部 , 4)
# (号館 , 4)
# (代理人 , 4)
# (09 , 4)
# (公式 , 4)
# (職名 , 4)
# (多種 , 4)
# (知識 , 4)
# (作成 , 4)
# (点検 , 4)
# (人員 , 4)
# (１月 , 4)
# (個人 , 4)
# (training , 4)
# (course , 4)
# (リンク , 4)
# (平均 , 4)
# (目次 , 4)
# (0422 , 4)
# (3814 , 4)
# (カード , 4)
# (近く , 4)
# (形成 , 4)
# (小規模 , 4)
# (従業 , 4)
# (クラブ , 4)
# (人材 , 4)
# (コーヒー , 4)
# (200 , 4)
# (220 , 4)
# (280 , 4)
# (TQC , 4)
# (SB , 4)
# (セミナー , 4)
# (金沢大学 , 4)
# (方針 , 4)
# (松本 , 4)
# (レストラン , 4)
# (タイム , 4)
# (丁目 , 4)
# (出身 , 4)
# (宇都宮大学 , 4)
# (電気通信大学 , 4)
# (ヶ月 , 4)
# (青山 , 4)
# (名誉 , 4)
# (立教大学 , 4)
# (0 , 4)
# (財団 , 4)
# (体育館 , 4)
# (リアル , 4)
# (料理 , 4)
# (資料 , 4)
# (合同 , 4)
# (佐藤 , 4)
# (博樹 , 4)
# (トップクラス , 4)
# (-～- , 4)
# (制作 , 4)
# (購入 , 4)
# (職場 , 4)
# (工業 , 4)
# (一橋大学 , 4)
# (賃金 , 4)
# (][ , 4)
# (副業 , 4)
# (ミドル , 4)
# (～; , 4)
# (視野 , 4)
# (年齢 , 4)
# (ニーズ , 4)
#  , 4)
# (エン , 4)
# (持株 , 4)
# (財形 , 4)
# (岐阜大学 , 4)
# (名古屋大学 , 4)
# (市立 , 4)
# (日月 , 4)
# (見舞 , 4)
# (175 , 4)
# (784 , 4)
# (東京理科大学 , 4)
# (井の頭線 , 4)
# (オフィシャルサイト , 4)
# (960 , 4)
# (水道 , 4)
# (始業 , 3)
# (終業 , 3)
# (福祉 , 3)
# (】. , 3)
# (P , 3)
# (みなさん , 3)
# (活用 , 3)
# (Program , 3)
# (育成 , 3)
# (常勤 , 3)
# (育休 , 3)
# (一定 , 3)
# (部門 , 3)
# (総務 , 3)
# (記入 , 3)
# (交付 , 3)
# (夜間 , 3)
# (画像 , 3)
# (表示 , 3)
# (敷地 , 3)
# (俸給 , 3)
# (相当 , 3)
# (貸付 , 3)
# (本部 , 3)
# (保健 , 3)
# (コミュニケーション , 3)
# (ランキング , 3)
# (理工 , 3)
# (協調 , 3)
# (ワンルーム , 3)
# (マンション , 3)
# (タイプ , 3)
# (遠方 , 3)
# (春季 , 3)
# (調査 , 3)
# ((~ , 3)
# (最前線 , 3)
# (化学 , 3)
# (全日 , 3)
# (43 , 3)
# (中等 , 3)
# (発達 , 3)
# (ご覧 , 3)
# (3812 , 3)
# (7336 , 3)
# (銀杏 , 3)
# (メトロ , 3)
# (37 , 3)
# (54 , 3)
# (締切 , 3)
# (計画 , 3)
# (icon , 3)
# (全面 , 3)
# (リニュ , 3)
# (ーアル , 3)
# (ビュッフェ , 3)
# (ライブ , 3)
# (キッチン , 3)
# (，. , 3)
# (ホール , 3)
# (レイアウト , 3)
# (一新 , 3)
# (快適 , 3)
# (2016 , 3)
# (在留 , 3)
# (早め , 3)
# (集中 , 3)
# (開講 , 3)
# (リサーチ , 3)
# (目黒 , 3)
# (裁量 , 3)
# (要件 , 3)
# (機関 , 3)
# (公開 , 3)
# (備考 , 3)
# (Academic , 3)
# (措置 , 3)
# (役職 , 3)
# (本人 , 3)
# (請求 , 3)
# (忌引 , 3)
# (個室 , 3)
# (貸与 , 3)
# (助産 , 3)
# (300 , 3)
# (問合せ , 3)
# (お客様 , 3)
# (番号 , 3)
# (日曜 , 3)
# (寄付 , 3)
# (報告 , 3)
# (公表 , 3)
# (内定 , 3)
# (１１月 , 3)
# (クチコミ , 3)
# (ギャップ , 3)
# (実証 , 3)
# (経理 , 3)
# (Excel , 3)
# (パソコン , 3)
# (日本語 , 3)
# (開催 , 3)
# (文学部 , 3)
# (教室 , 3)
# (06 , 3)
# (喚起 , 3)
# (NEW , 3)
# (学務 , 3)
# (ポイント , 3)
# (診療 , 3)
# (審査 , 3)
# (会議 , 3)
# (以降 , 3)
# (事前 , 3)
# (完全 , 3)
# (html , 3)
# (3449 , 3)
# (閉室 , 3)
# (ポリシー , 3)
# (  , 3)
# (月額 , 3)
# (規模 , 3)
# (標準 , 3)
# (明らか , 3)
# (学外 , 3)
# (講習 , 3)
# (500 , 3)
# (個別 , 3)
# (1541 , 3)
# (Copyright , 3)
# (All , 3)
# (Rights , 3)
# (処理 , 3)
# (金曜 , 3)
# (応援 , 3)
# (the , 3)
# (比較 , 3)
# (08 , 3)
# (当社 , 3)
# (社長 , 3)
# (ドリンク , 3)
# (当時 , 3)
# (参加 , 3)
# (社名 , 3)
# (ハウス , 3)
# (はじめ , 3)
# (いま , 3)
# (信州大学 , 3)
# (山梨大学 , 3)
# (ローリング , 3)
# (考案 , 3)
# (命名 , 3)
# (メイン , 3)
# (ウェブサイト , 3)
# (補足 , 3)
# (ツイート , 3)
# (自由 , 3)
# (どなた , 3)
# (フォロー , 3)
# (礼儀 , 3)
# (知らず , 3)
# (ブロック , 3)
# (Joined , 3)
# (June , 3)
# (プロ , 3)
# (横浜 , 3)
# (名古屋 , 3)
# (` , 3)
# (大江戸 , 3)
# (from , 3)
# (年始 , 3)
# (Kavli , 3)
# (IPMU , 3)
# (拠点 , 3)
# (本格 , 3)
# (眼科 , 3)
# (中学 , 3)
# (相川 , 3)
# (PTA , 3)
# (丸山 , 3)
# (康昭 , 3)
# (木村 , 3)
# (都道府県 , 3)
# (神吉 , 3)
# (賢一 , 3)
# (市町村 , 3)
# (有識者 , 3)
# (野田 , 3)
# (一夫 , 3)
# (多摩大 , 3)
# (学長 , 3)
# (伊藤 , 3)
# (元重 , 3)
# (安島 , 3)
# (博幸 , 3)
# (リフレッシュ , 3)
# (ログ , 3)
# (ユーザー , 3)
# (満載 , 3)
# (専念 , 3)
# (理事 , 3)
# (現状 , 3)
# (お越し , 3)
# (上智大学 , 3)
# (外部 , 3)
# (編集 , 3)
# (生徒 , 3)
# (機能 , 3)
# (社内 , 3)
# (設置 , 3)
# (渋谷 , 3)
# (正社員 , 3)
# (弊社 , 3)
# (市民 , 3)
# (北海道 , 3)
# (ナビ , 3)
# (祝い金 , 3)
# (在庫 , 3)
# (設立 , 3)
# (上司 , 3)
# (柔軟 , 3)
# (清掃 , 3)
# (ハウジング , 3)
# (アドバイザー , 3)
# (部屋 , 3)
# (～（ , 3)
# (スカウト , 3)
# (オープン , 3)
# (飲食 , 3)
# (永年 , 3)
# (投稿 , 3)
# (Web , 3)
# (茨城大学 , 3)
# (京都 , 3)
# (府立 , 3)
# (広告 , 3)
# (月内 , 3)
# (122 , 3)
# (保障 , 3)
# (群馬 , 3)
# (神戸大学 , 3)
# (学院 , 3)
# (女子 , 3)
# (広島 , 3)
# (高専 , 3)
# (病棟 , 3)
# (独身 , 3)
# (カ所 , 3)
# (バイト , 3)
# (125 , 3)
# (愛知 , 3)
# (見込み , 3)
# (修了 , 3)
# (アミューズメント , 3)
# ( , 3)
# (710 , 3)
# (安心 , 3)
# (1296 , 3)
# (1060 , 3)
# (990 , 3)
# (シニア , 3)
# (日勤 , 3)
# (退勤 , 2)
# (時刻 , 2)
# (昭和 , 2)
# (労基法 , 2)
# (同居 , 2)
# (English , 2)
# (space , 2)
# (新た , 2)
# (主体 , 2)
# (フィールド , 2)
# (グローバル , 2)
# (UTokyo , 2)
# (年数 , 2)
# (参照 , 2)
# (延長 , 2)
# (別紙 , 2)
# (記載 , 2)
# (満了 , 2)
# (医科研 , 2)
# (根拠 , 2)
# (P , 2)
# (いちょう , 2)
# (病後 , 2)
# (拡大 , 2)
# (0 , 2)
# (心身 , 2)
# (末日 , 2)
# (給付 , 2)
# (直営 , 2)
# (診断 , 2)
# (保護 , 2)
# (不足 , 2)
# (赴任 , 2)
# (閉館 , 2)
# (おすすめ , 2)
# (開館 , 2)
# (歴代 , 2)
# (館長 , 2)
# (著作 , 2)
# (ポスター , 2)
#  , 2)
# (>[ , 2)
# (訂正 , 2)
# (発行 , 2)
# (人間 , 2)
# (一部 , 2)
# (観点 , 2)
# (創発 , 2)
# (効果 , 2)
# (検証 , 2)
# (27997 , 2)
# (64 , 2)
# (配属 , 2)
# (進路 , 2)
# (大学院生 , 2)
# (window , 2)
# (140 , 2)
# (前日 , 2)
# (当日 , 2)
# (Top , 2)
# (留学 , 2)
# (事情 , 2)
# (最長 , 2)
# (大変 , 2)
# (インターンシップ , 2)
# (部長 , 2)
# (記事 , 2)
# (物理 , 2)
# (The , 2)
# (University , 2)
# (in , 2)
# (Information , 2)
# (Studies , 2)
# (Campus , 2)
# (Bunkyo , 2)
# (ku , 2)
# (JAPAN , 2)
# (153 , 2)
# (8902 , 2)
# (Komaba , 2)
# (クラス , 2)
# (出願 , 2)
# (学位 , 2)
# (外国 , 2)
# (補佐 , 2)
# (OECD , 2)
# (イノベーションスクールネットワーク , 2)
# (ISN , 2)
# (tokyo , 2)
# (ac , 2)
# (西洋 , 2)
# (史学 , 2)
# (雑誌 , 2)
# (最終 , 2)
# (進入 , 2)
# (サマー , 2)
# (農学 , 2)
# (7135 , 2)
# ():: , 2)
# (Food , 2)
# (Cafe , 2)
# (移転 , 2)
# (依頼 , 2)
# (準用 , 2)
# (冷暖房 , 2)
# (賃料 , 2)
# (共益 , 2)
# (ユニフォーム , 2)
# (管掌 , 2)
# (職歴 , 2)
# (注文 , 2)
# (毎週 , 2)
# (学士 , 2)
# (チャート , 2)
# (時季 , 2)
# (本校 , 2)
# (普通 , 2)
# (理論 , 2)
# (支出 , 2)
# (Word , 2)
# (郵送 , 2)
# (本館 , 2)
# (助産婦 , 2)
# (身分 , 2)
# (運転 , 2)
# (パスポート , 2)
# (受取 , 2)
# (質問 , 2)
# (5841 , 2)
# (アット , 2)
# (受講 , 2)
# (HP , 2)
# (勧誘 , 2)
# (増加 , 2)
# (振興 , 2)
# (DC , 2)
# (優先 , 2)
# (カウンター , 2)
# (薬学部 , 2)
# (物質 , 2)
# (機器 , 2)
# (）: , 2)
# (ワード , 2)
# (Windows , 2)
# (レセプト , 2)
# (DPC , 2)
# (カルテ , 2)
# (届出 , 2)
# (欠員 , 2)
# (適性 , 2)
# (若干 , 2)
# (意欲 , 2)
# (患者 , 2)
# (仕組み , 2)
# (上記 , 2)
# (内科 , 2)
# (神経 , 2)
# (110 , 2)
# (木材 , 2)
# (マーケティング , 2)
# (F , 2)
# (8972 , 2)
# (不可 , 2)
# (プライバシー , 2)
# (お話 , 2)
# (解決 , 2)
# (夏休み , 2)
# (来年度 , 2)
# (全体 , 2)
# (計上 , 2)
# (学芸 , 2)
# (Teacher , 2)
# (Curator , 2)
# (Re , 2)
# (admission , 2)
# (プロフィール , 2)
# (シラバス , 2)
# (Calender , 2)
# (and , 2)
# (Annual , 2)
# (Schedule , 2)
# (住居 , 2)
# (5452 , 2)
# (3481 , 2)
# (9311 , 2)
# (鶴川 , 2)
# (80 , 2)
# (雑則 , 2)
# (附則 , 2)
# (  , 2)
# (8391 , 2)
# (8427 , 2)
# (TUO , 2)
# (定款 , 2)
# (WEB , 2)
# (一言 , 2)
# (Reserved , 2)
# (サブ , 2)
# (ウェイ , 2)
# (エリア , 2)
# (utcoop , 2)
# (or , 2)
# (新入生 , 2)
# (要因 , 2)
# (疾病 , 2)
# (世話 , 2)
# (予防 , 2)
# (ブログ , 2)
# (家庭 , 2)
# (教師 , 2)
# (援助 , 2)
# (静か , 2)
# (勉強 , 2)
# (TOP , 2)
# (230 , 2)
# (350 , 2)
# (成人 , 2)
# (大会 , 2)
# (co , 2)
# (` , 2)
# (協同 , 2)
# (合宿 , 2)
# (運動 , 2)
# (空き , 2)
# (ローン , 2)
# (多目的 , 2)
# (名古屋大 , 2)
# (ムラカミ , 2)
# (GRILL , 2)
# (カメリア , 2)
# (ラウンジ , 2)
# (テクノ , 2)
# (グループ , 2)
# (マイナビ , 2)
# (要綱 , 2)
# (体制 , 2)
# (確定 , 2)
# (拠出 , 2)
# (minutes , 2)
# (walk , 2)
# (sanchome , 2)
# (Station , 2)
# (Line , 2)
# (創業 , 2)
# (年末 , 2)
# (先輩 , 2)
# (北見工業大学 , 2)
# (岩手大学 , 2)
# (茨城 , 2)
# (横浜国立大学 , 2)
# (横浜市立大学 , 2)
# (海洋 , 2)
# (90 , 2)
# (単独 , 2)
# (観測 , 2)
# (成功 , 2)
# (JAXA , 2)
# (イメージング , 2)
# (うち , 2)
# (連休 , 2)
# (ほう , 2)
# (初期 , 2)
# (合格 , 2)
# (外来 , 2)
# (将来 , 2)
# (選択 , 2)
# (件数 , 2)
# (グラウンド , 2)
# (プール , 2)
# (体育 , 2)
# (マッサージ , 2)
# (ベネフィット・ワン , 2)
# (新規 , 2)
# (階層 , 2)
# (会計 , 2)
# (統一 , 2)
# (文科 , 2)
# (分煙 , 2)
# (禁煙 , 2)
# (61 , 2)
# (免除 , 2)
# (新宿 , 2)
# (160 , 2)
# (バス , 2)
# (隙間 , 2)
# (古賀 , 2)
# (伸明 , 2)
# (向山 , 2)
# (行雄 , 2)
# (小学 , 2)
# (新藤 , 2)
# (久典 , 2)
# (全日本 , 2)
# (代表 , 2)
# (バランス , 2)
# (取り組み , 2)
# (序章 , 2)
# (時代 , 2)
# (武石 , 2)
# (恵美子 , 2)
# (高崎 , 2)
# (大学生 , 2)
# (機会 , 2)
# (京都大 , 2)
# (芝浦工業大学 , 2)
# (脚注 , 2)
# (施行 , 2)
# (農繁期 , 2)
# (年代 , 2)
# (児童 , 2)
# (長野 , 2)
# (Qualifications , 2)
# (MRI , 2)
# (Compensation , 2)
# (Application , 2)
# (period , 2)
# (業績 , 2)
# (カ月 , 2)
# (-～-. , 2)
# (トップ , 2)
# (口座 , 2)
# (開設 , 2)
# (撮影 , 2)
# (以内 , 2)
# (非常勤 , 2)
# (深刻 , 2)
# (ベンチャー , 2)
# (責任 , 2)
# (資金 , 2)
# (戦略 , 2)
# (産業 , 2)
# (人的 , 2)
# (受賞 , 2)
# (市場 , 2)
# (変動 , 2)
# (企画 , 2)
# (具体 , 2)
# (変化 , 2)
# (米国 , 2)
# (120 , 2)
# (毎年 , 2)
# (ビジネス , 2)
# (日本円 , 2)
# (前文 , 2)
# (蓄積 , 2)
# (水準 , 2)
# (学問 , 2)
# (牽引 , 2)
# (公正 , 2)
# (進歩 , 2)
# (創造 , 2)
# (貢献 , 2)
# (エリート , 2)
# (目標 , 2)
# (資質 , 2)
# (門戸 , 2)
# (洞察 , 2)
# (想像 , 2)
# (開拓 , 2)
# (付属 , 2)
# (毎日 , 2)
# (.. , 2)
# (いつ , 2)
# (シート , 2)
# (振り分け , 2)
# (最寄り , 2)
# (フォレスタ , 2)
# (都営 , 2)
# (平和 , 2)
# (.... , 2)
# (65 , 2)
# (直面 , 2)
# (離職 , 2)
# (リスク , 2)
# (遠距離 , 2)
# (働き , 2)
# (manaba , 2)
# (ポートフォリオ , 2)
# (板橋 , 2)
# (829592 , 2)
# (852898 , 2)
# (立ち , 2)
# (上げ , 2)
# (つながり , 2)
# (勁草 , 2)
# (ハイメディック・ , 2)
# (検診 , 2)
# (415 , 2)
# (462 , 2)
# (うえ , 2)
# (会員 , 2)
# (移植 , 2)
# (緊急 , 2)
# (唐辛子 , 2)
# (ひとつ , 2)
# (学費 , 2)
# (貯蓄 , 2)
# (山形大学 , 2)
# (ディレクター , 2)
# (カナウ , 2)
# (紙面 , 2)
# (デザイン , 2)
# (誕生 , 2)
# (実態 , 2)
# (岩永 , 2)
# (エプロン , 2)
# (表彰 , 2)
# (愛媛大学 , 2)
# (大阪市立大学 , 2)
# (佐賀 , 2)
# (静岡 , 2)
# (創価大学 , 2)
# (畜産 , 2)
# (帝京大学 , 2)
# (専修大学 , 2)
# (東海 , 2)
# (転勤 , 2)
# (雰囲気 , 2)
# (オリーヴ , 2)
# (文字 , 2)
# (湯島 , 2)
# (開放 , 2)
# (市内 , 2)
# (積極 , 2)
# (発想 , 2)
# (たち , 2)
# (多く , 2)
# (自身 , 2)
# (随時 , 2)
# (上旬 , 2)
# (本社 , 2)
# (支店 , 2)
# (保養 , 2)
# (青山学院 , 2)
# (環境省 , 2)
# (自然 , 2)
# (公園 , 2)
# (カナダ , 2)
# (意味 , 2)
# (オフィス , 2)
# (最低 , 2)
# (an , 2)
# (不要 , 2)
# (チカ , 2)
# (疾患 , 2)
# (最先端 , 2)
# (Externship , 2)
# (成果 , 2)
# (反対 , 2)
# (意見 , 2)
# (アクアレスキュー , 2)
# (視察 , 2)
# (とい , 1)
# (細目 , 1)
# (親子 , 1)
# (中旬 , 1)
# (終日 , 1)
# (TOKYO , 1)
# (twitter , 1)
# (facebook , 1)
# (youtube , 1)
# (提携 , 1)
# (有効 , 1)
# (期待 , 1)
# (キーワード , 1)
# (名称 , 1)
# (PEAK , 1)
# (リーディング , 1)
# (スタディ , 1)
# (FS , 1)
# (FLY , 1)
# (自主 , 1)
# (リーダー , 1)
# (OpenCourseWare , 1)
# (ここ , 1)
# (解説 , 1)
# (部局 , 1)
# (入退院 , 1)
# (付き添い , 1)
# (修学 , 1)
# (持ち , 1)
# (意思 , 1)
# (文書 , 1)
# (就労 , 1)
# (任命 , 1)
# (。) , 1)
# (申し出 , 1)
# (月極 , 1)
# (一時 , 1)
# (ひよこ , 1)
# (ケア , 1)
# (クリック , 1)
# (本番 , 1)
# (留意 , 1)
# (別々 , 1)
# (十分 , 1)
# (要求 , 1)
# (一昨年 , 1)
# (不良 , 1)
# (故障 , 1)
# (適当 , 1)
# (初日 , 1)
# (割り , 1)
# (看病 , 1)
# (適用 , 1)
# (積立 , 1)
# (貯金 , 1)
# (各地 , 1)
# (入れ , 1)
# (特殊 , 1)
# (なん , 1)
# (ピアサポートルーム , 1)
# (46182 , 1)
# (7145 , 1)
# (7146 , 1)
# (人文 , 1)
# (歴史 , 1)
# (ランク , 1)
# (イン , 1)
# (学籍 , 1)
# (入力 , 1)
# (熱意 , 1)
# (周囲 , 1)
# (空き室 , 1)
# (退去 , 1)
# (引越し , 1)
# (費用 , 1)
# (こども , 1)
# (ブック , 1)
# (用紙 , 1)
# (片付け , 1)
# (修正 , 1)
# ()】《 , 1)
# (127 , 1)
# ()】< , 1)
# ()】. , 1)
# (トピックス , 1)
# (エッセイ , 1)
# (パンフレット , 1)
# (虎の巻 , 1)
# (俯瞰 , 1)
# (原子 , 1)
# (分解能 , 1)
# (顕微鏡 , 1)
# (反応 , 1)
# (追跡 , 1)
# (本棚 , 1)
# (温暖 , 1)
# (－. , 1)
# (見聞 , 1)
# (ヨーロッパ , 1)
# (各国 , 1)
# (ポスドク , 1)
# (原始 , 1)
# (交歓 , 1)
# (小石川 , 1)
# (植物 , 1)
# ()~. , 1)
# (◇. , 1)
# (店頭 , 1)
# (PRONTO , 1)
# (56 , 1)
# (95 , 1)
# (277 , 1)
# (47 , 1)
# (117 , 1)
# (96 , 1)
# (～, , 1)
# (〜, , 1)
# (ﾏﾃﾘｱﾙ , 1)
# (ﾚﾎﾟｰﾄ , 1)
# (要旨 , 1)
# (graduate , 1)
# (info , 1)
# (アド , 1)
# (ミニ , 1)
# (importance , 1)
# (アラート , 1)
# (廃止 , 1)
# (安否 , 1)
# (運用 , 1)
# (アカウント , 1)
# (パスワード , 1)
# (館内 , 1)
# (毎月 , 1)
# (休館 , 1)
# (入国 , 1)
# (判断 , 1)
# (〕. , 1)
# (特段 , 1)
# (期限 , 1)
# (不法 , 1)
# (滞在 , 1)
# (混雑 , 1)
# (医学 , 1)
# (通年 , 1)
# (必修 , 1)
# (イングリッシュ , 1)
# (レッスン , 1)
# (講座 , 1)
# (リオティント , 1)
# (フェロー , 1)
# (近況 , 1)
# (金属 , 1)
# (磁性 , 1)
# (電界 , 1)
# (制御 , 1)
# (ミクロ , 1)
# (メカニズム , 1)
# (解明 , 1)
# (小山 , 1)
# (知弘 , 1)
# (大地 , 1)
# (02 , 1)
# (マイクロ , 1)
# (光子 , 1)
# (吸収 , 1)
# (検出 , 1)
# (no , 1)
# (layouts , 1)
# (found , 1)
# (学際 , 1)
# (学府 , 1)
# (Interfaculty , 1)
# (Initiative , 1)
# (Graduate , 1)
# (School , 1)
# (Interdisciplinary , 1)
# (Meguro , 1)
# (原著 , 1)
# (特許 , 1)
# (算出 , 1)
# (seiyoshi , 1)
# (専修 , 1)
# (欧米 , 1)
# (Claudia , 1)
# (Rapp , 1)
# (49 , 1)
# (クリオ , 1)
# (バック , 1)
# (ナンバー , 1)
# (231 , 1)
# (網掛 , 1)
# (SP , 1)
# (リテラシー , 1)
# (8117 , 1)
# (8119 , 1)
# (Notification , 1)
# (Office , 1)
# (Relocation , 1)
# (大学入試センター , 1)
# (Lecture , 1)
# (Cancellation , 1)
# (on , 1)
# (rd , 1)
# (October , 1)
# (切り替え , 1)
# (再掲 , 1)
# (日割り , 1)
# (即時 , 1)
# (権利 , 1)
# (法事 , 1)
# (交代 , 1)
# (合計 , 1)
# (大卒 , 1)
# (245 , 1)
# (214 , 1)
# (281 , 1)
# (495 , 1)
# (234 , 1)
# (759 , 1)
# (288 , 1)
# (859 , 1)
# (248 , 1)
# (560 , 1)
# (426 , 1)
# (303 , 1)
# (986 , 1)
# (256 , 1)
# (925 , 1)
# (832 , 1)
# (312 , 1)
# (757 , 1)
# (オフィシャルグッズ , 1)
# (到着 , 1)
# (まま , 1)
# (経過 , 1)
# (UTCC , 1)
# (返送 , 1)
# (名前 , 1)
# (住所 , 1)
# (済み , 1)
# (受注 , 1)
# (回答 , 1)
# (父母 , 1)
# (位記 , 1)
# (授与 , 1)
# (正常 , 1)
# (P , 1)
# (協定 , 1)
# (一貫 , 1)
# (出納 , 1)
# (収入 , 1)
# (月間 , 1)
# (関数 , 1)
# (掲示 , 1)
# (ＨＰ , 1)
# (5009 , 1)
# (5008 , 1)
# (25009 , 1)
# (25008 , 1)
# (kyoumu , 1)
# (ofc , 1)
# (adc , 1)
# (（[ , 1)
# (ログイン , 1)
# (大切 , 1)
# (中級 , 1)
# (追加 , 1)
# (追記 , 1)
# (ゼミナール , 1)
# (理科 , 1)
# (聴講 , 1)
# (禁止 , 1)
# (熱中 , 1)
# (発生 , 1)
# (防犯 , 1)
# (徹底 , 1)
# (ゴールデンウィーク , 1)
# (課外 , 1)
# (飲酒 , 1)
# (Precautions , 1)
# (for , 1)
# (drinking , 1)
# (自転車 , 1)
# (事故 , 1)
# (学研 , 1)
# (災害 , 1)
# (傷害 , 1)
# (S , 1)
# (しかた , 1)
# (ガイド , 1)
# (相席 , 1)
# (3971 , 1)
# (3973 , 1)
# (): , 1)
# (保守 , 1)
# (当たり , 1)
# (所掌 , 1)
# (エクセル , 1)
# (パワー , 1)
# (ソフト , 1)
# (PC , 1)
# (円滑 , 1)
# (英会話 , 1)
# (原則 , 1)
# (手元 , 1)
# (用意 , 1)
# (あて先 , 1)
# (来院 , 1)
# (受診 , 1)
# (呼吸 , 1)
# (心療内科 , 1)
# (麻酔 , 1)
# (乳腺 , 1)
# (内分泌 , 1)
# (外科 , 1)
# (蔵書 , 1)
# (法文 , 1)
# (漢籍 , 1)
# (分散 , 1)
# (per , 1)
# (加工 , 1)
# (流通 , 1)
# ([2 , 1)
# (0 , 1)
# (若葉 , 1)
# (ダイニング , 1)
# (7147 , 1)
# (3465 , 1)
# (3446 , 1)
# (8946 , 1)
# (5793 , 1)
# (7579 , 1)
# (0711 , 1)
# (2280 , 1)
# (文具 , 1)
# (家具 , 1)
# (家電 , 1)
# (0714 , 1)
# (2284 , 1)
# (再任 , 1)
# (所属 , 1)
# (部会 , 1)
# (  , 1)
# (―. , 1)
# (2002 , 1)
# (広報 , 1)
# (3811 , 1)
# (5481 , 1)
# (5803 , 1)
# (9188 , 1)
# (` , 1)
# (提案 , 1)
# (適切 , 1)
# (取扱い , 1)
# (責務 , 1)
# (.. , 1)
# (優遇 , 1)
# (MATLAB , 1)
# (Bash , 1)
# (プログラミング , 1)
# (URL , 1)
# (完了 , 1)
# (全学 , 1)
# (ＣＡＰ , 1)
# (上表 , 1)
# (借用 , 1)
# (文系 , 1)
# (今回 , 1)
# (id , 1)
# (samidaretaro , 1)
# (20140812233913 , 1)
# (plain , 1)
# (同日 , 1)
# (言及 , 1)
# (Google , 1)
# (252 , 1)
# (262 , 1)
# (あたり , 1)
# (変形 , 1)
# (当直 , 1)
# (6700 , 1)
# (6701 , 1)
# (A , 1)
# (前条 , 1)
# (生死 , 1)
# (不明 , 1)
# (.. , 1)
# (お茶 , 1)
# (株式 , 1)
# (半導体 , 1)
# (エネルギー , 1)
# (厚木 , 1)
# (中高生 , 1)
# (指導 , 1)
# (ena , 1)
# (町田 , 1)
# (365 , 1)
# (820 , 1)
# (  , 1)
# (セメスター・ , 1)
# (二分 , 1)
# (併用 , 1)
# (それら , 1)
# (81272 , 1)
# (1542 , 1)
# (5800 , 1)
# (8398 , 1)
# (野菜 , 1)
# (フリー , 1)
# (限度 , 1)
# (R9 , 1)
# (向上 , 1)
# (各自 , 1)
# (代用 , 1)
# (グラント , 1)
# (任用 , 1)
# (柏の葉 , 1)
# (旅費 , 1)
# (５月 , 1)
# (学力 , 1)
# (mail , 1)
# (体力 , 1)
# (自信 , 1)
# (事務職 , 1)
# (月曜 , 1)
# (map , 1)
# (time , 1)
# (受験生 , 1)
# (3818 , 1)
# (3304 , 1)
# (44812 , 1)
# (9050 , 1)
# (9053 , 1)
# (STAFF , 1)
# (Only , 1)
# (トップページ , 1)
# (Problems , 1)
# (Job , 1)
# (Continuity , 1)
# (Support , 1)
# (at , 1)
# (Small , 1)
# (Organization , 1)
# (池田 , 1)
# (IKEDA , 1)
# (Shingou , 1)
# (Keywords , 1)
# (継続 , 1)
# (,. , 1)
# (950 , 1)
# (kb , 1)
# (抄録 , 1)
# (未満 , 1)
# (負傷 , 1)
# (What , 1)
# (New , 1)
# (民間 , 1)
# (懇親 , 1)
# (お誘い , 1)
# (官庁 , 1)
# (手続 , 1)
# (重複 , 1)
# (読者 , 1)
# (上田 , 1)
# (昌典 , 1)
# (音楽 , 1)
# (backingham , 1)
# (nicks , 1)
# (伊田 , 1)
# (テクノス , 1)
# (idatechnos , 1)
# (jinji , 1)
# (RANRUN , 1)
# (スタッフブログ , 1)
# (sports , 1)
# (ranrun , 1)
# (松江 , 1)
# (セパタクロー , 1)
# (matsue , 1)
# (sepak , 1)
# (失敗 , 1)
# (xn , 1)
# (-- , 1)
# (ccke , 1)
# (jv , 1)
# (udy , 1)
# (harumscarum , 1)
# (kemushinitaberareta , 1)
# (インカレ , 1)
# (サークル , 1)
# (EVER , 1)
# (incolleever , 1)
# (bG9 , 1)
# (適材適所 , 1)
# (エイジェント , 1)
# (発明 , 1)
# (事例 , 1)
# (0 , 1)
# (インタビュー , 1)
# (ゴールデンウイーク , 1)
# (P , 1)
# (ドメイン , 1)
# (変則 , 1)
# (都度 , 1)
# (放課後 , 1)
# (印刷 , 1)
# (了承 , 1)
# (イメージ , 1)
# (照明 , 1)
# (演出 , 1)
# (店内 , 1)
# (ホット , 1)
# (一息 , 1)
# (友達 , 1)
# (おしゃべり , 1)
# (お供 , 1)
# (オーダー , 1)
# (香り , 1)
# (賞味 , 1)
# (MENU , 1)
# (ブレンド , 1)
# (エスプレッソ , 1)
# (カフェラテ , 1)
# (カプチーノ , 1)
# (キャラメルマキアート , 1)
# (モカ , 1)
# (紅茶 , 1)
# (抹茶 , 1)
# (ラテ , 1)
# (アイス , 1)
# (アタック , 1)
# (出場 , 1)
# (放送 , 1)
# (リアルタイム , 1)
# (視聴 , 1)
# (同級生 , 1)
# (偶然 , 1)
# (オンエア , 1)
# (わけ , 1)
# (スーツ , 1)
# (https , 1)
# (qod , 1)
# (Bi , 1)
# (sCA , 1)
# (ススメポ , 1)
# (消費 , 1)
# (平方メートル , 1)
# (面積 , 1)
# (サッカー , 1)
# (テニス , 1)
# (コート , 1)
# (野球 , 1)
# (ラグビー , 1)
# (クロスカントリー , 1)
# (併設 , 1)
# (日帰り , 1)
# (information , 1)
# (新着 , 1)
# (工学部 , 1)
# (建築 , 1)
# (通信 , 1)
# (日比谷 , 1)
# (椿山荘 , 1)
# (カポ・ペリカーノ , 1)
# (御殿 , 1)
# (東証 , 1)
# (上場 , 1)
# (ホールディングス , 1)
# (残業 , 1)
# (全額 , 1)
# (広多賀谷 , 1)
# (省エネルギー , 1)
# (みなさま , 1)
# (以前 , 1)
# (お伝え , 1)
# (山中 , 1)
# (内藤 , 1)
# (始め , 1)
# (abreuvoir , 1)
# (yamanaka , 1)
# (@ , 1)
# (P , 1)
# (SE , 1)
# (借家 , 1)
# (福山 , 1)
# (場外 , 1)
# (フレックス , 1)
# (コア , 1)
# (75 , 1)
# (両日 , 1)
# (川上 , 1)
# (予測 , 1)
# (春日 , 1)
# (ダイワ , 1)
# (ユビキタス , 1)
# (丸ノ内線 , 1)
# (5802 , 1)
# (5577 , 1)
# (Daiwa , 1)
# (Ubiquitous , 1)
# (Research , 1)
# (Building , 1)
# (Ward , 1)
# (located , 1)
# (nearby , 1)
# (Kasuga , 1)
# (Gate , 1)
# (inside , 1)
# (campus , 1)
# (Marunouchi , 1)
# (Oedo , 1)
# (国公立 , 1)
# (室蘭工業大学 , 1)
# (弘前大学 , 1)
# (秋田 , 1)
# (長岡 , 1)
# (都立 , 1)
# (短期 , 1)
# (大栗 , 1)
# (真宗 , 1)
# (重力 , 1)
# (レンズ , 1)
# (現象 , 1)
# (光年 , 1)
# (発見 , 1)
# (記録 , 1)
# (.. , 1)
# (-「 , 1)
# (ガンマ線 , 1)
# (始動 , 1)
# (メンバー , 1)
# (スーパーローテート , 1)
# (か月 , 1)
# (独り立ち , 1)
# (長期間 , 1)
# (入局 , 1)
# (高岡 , 1)
# (美佳 , 1)
# (島津 , 1)
# (明人 , 1)
# (産休 , 1)
# (サプリ , 1)
# (SUBWAY , 1)
# (サンドイッチ , 1)
# (原子力 , 1)
# (青森 , 1)
# (33 , 1)
# (減額 , 1)
# (承認 , 1)
# (JR , 1)
# (スーパー , 1)
# (あずさ , 1)
# (電鉄 , 1)
# (新島 , 1)
# (乗鞍高原 , 1)
# (60 , 1)
# (乗鞍 , 1)
# (周遊 , 1)
# (シャトル , 1)
# (dQ9 , 1)
# (いっぱい , 1)
# (潜入 , 1)
# (繰越 , 1)
# (  , 1)
# (剛史 , 1)
# (ローソン , 1)
# (取締役 , 1)
# (ＣＥＯ , 1)
# (` , 1)
# (促進 , 1)
# (注目 , 1)
# (もと , 1)
# (Topic , 1)
# (2020 , 1)
# (美佐 , 1)
# (852894 , 1)
# (以来 , 1)
# (長年 , 1)
# (基盤 , 1)
# (着実 , 1)
# (強化 , 1)
# (最大限 , 1)
# ((@ , 1)
# (shirucafe , 1)
# (赤門 , 1)
# (WiFi , 1)
# (コンセント , 1)
# (コマ , 1)
# (是非 , 1)
# (気軽 , 1)
# (半休 , 1)
# (青山学院大学 , 1)
# (学習院 , 1)
# (女子大 , 1)
# (国際基督教大学 , 1)
# (東京女子大学 , 1)
# (東洋大学 , 1)
# (休養 , 1)
# (同行 , 1)
# (57 , 1)
# (やすみ , 1)
# (項目 , 1)
# (比定 , 1)
# (農村 , 1)
# (地帯 , 1)
# (家業 , 1)
# (呼称 , 1)
# (中間 , 1)
# (稲刈り , 1)
# (山形 , 1)
# (1990 , 1)
# (存続 , 1)
# (お手伝い , 1)
# (指示 , 1)
# (!! , 1)
# (ナシ , 1)
# (明け , 1)
# (そば , 1)
# (♪. , 1)
# (ダイヤル , 1)
# (050 , 1)
# (5500 , 1)
# (確か , 1)
# (折返し , 1)
# (東新宿 , 1)
# (技能 , 1)
# (出社 , 1)
# (112 , 1)
# (GW , 1)
# (白金台 , 1)
# (安田 , 1)
# (講堂 , 1)
# (5665 , 1)
# (7860 , 1)
# (ATM , 1)
# (～-. , 1)
# (生体 , 1)
# (認証 , 1)
# (ＩＣ , 1)
# (ＡＴＭ , 1)
# (アクセシビリティ , 1)
# (セキュリティ , 1)
# (三井 , 1)
# (住友 , 1)
# (銀行 , 1)
# (取引 , 1)
# (出版 , 1)
# (アルバム , 1)
# (97 , 1)
# (洗濯 , 1)
# (榎本 , 1)
# (昌一 , 1)
# (清算 , 1)
# (フレキシブル , 1)
# (組合せ , 1)
# (退社 , 1)
# (積算 , 1)
# (復帰 , 1)
# (半日 , 1)
# (ヒビヤマツモトロウグリル , 1)
# (洋食 , 1)
# (労働省 , 1)
# (記者 , 1)
# (会見 , 1)
# (大半 , 1)
# (止め , 1)
# (主張 , 1)
# (公的 , 1)
# (コンプライアンス , 1)
# (正規 , 1)
# (警鐘 , 1)
# (筆者 , 1)
# (根底 , 1)
# (今年度 , 1)
# (候補 , 1)
# (EMURGO , 1)
# (720 , 1)
# (調達 , 1)
# (パートナー , 1)
# (Input , 1)
# (Output , 1)
# (1953 , 1)
# (学者 , 1)
# (生まれ , 1)
# (津田 , 1)
# (師事 , 1)
# (近年 , 1)
# (資源 , 1)
# (労使 , 1)
# (冲永 , 1)
# (著書 , 1)
# (共著 , 1)
# (編著 , 1)
# (共編 , 1)
# (1971 , 1)
# (桐朋 , 1)
# (1976 , 1)
# (社会学部 , 1)
# (1978 , 1)
# (変質 , 1)
# (供給 , 1)
# (制約 , 1)
# (樋口 , 1)
# (美雄 , 1)
# (商学部 , 1)
# (主査 , 1)
# (））; , 1)
# (料金 , 1)
# (ルール , 1)
# (名目 , 1)
# (上昇 , 1)
# (—: , 1)
# (脇田 , 1)
# (景気 , 1)
# (格差 , 1)
# (佐々木 , 1)
# (宮本 , 1)
# (付加 , 1)
# (価値 , 1)
# (生産 , 1)
# (配分 , 1)
# (塩路 , 1)
# (悦朗 , 1)
# (持続 , 1)
# (成長 , 1)
# (資本 , 1)
# (フリーター , 1)
# (` , 1)
# (在籍 , 1)
# (人口 , 1)
# (役割 , 1)
# (進出 , 1)
# (過程 , 1)
# (アメリカ , 1)
# (創出 , 1)
# (セクター , 1)
# (1600 , 1)
# (ドル , 1)
# (売上 , 1)
# (210 , 1)
# (5000 , 1)
# (税収 , 1)
# (971 , 1)
# (発揮 , 1)
# (経歴 , 1)
# (自己 , 1)
# (PR , 1)
# (書き方 , 1)
# (ハローワーク , 1)
# (参考 , 1)
# (週末 , 1)
# (言語 , 1)
# (中国 , 1)
# (仕方 , 1)
# (咨询 , 1)
# (开放 , 1)
# (时间 , 1)
# (时咨 , 1)
# (预约 , 1)
# (カウンセリング , 1)
# (受験 , 1)
# (現役 , 1)
# (.【 , 1)
# (富士通 , 1)
# (UI , 1)
# (アクティブ , 1)
# (ラーニング , 1)
# (39 , 1)
# (41 , 1)
# (42 , 1)
# (ランチ , 1)
# (ディナー , 1)
# (ファカルティクラブ , 1)
# (お盆 , 1)
# (江戸 , 1)
# (申込 , 1)
# (勝手 , 1)
# (経緯 , 1)
# (終戦 , 1)
# (食糧 , 1)
# (物資 , 1)
# (戦災 , 1)
# (校舎 , 1)
# (消失 , 1)
# (食料 , 1)
# (事実 , 1)
# (休校 , 1)
# (改善 , 1)
# (動き , 1)
# (戦時 , 1)
# (ペン , 1)
# (絶対 , 1)
# (サクセス , 1)
# (アカデミー , 1)
# (丸の内 , 1)
# (分の , 1)
# (院内 , 1)
# (大型 , 1)
# (レジャー , 1)
# (ベネフィットステーション , 1)
# (優待 , 1)
# (割引 , 1)
# (ドトールコーヒー , 1)
# (ショップ , 1)
# (UT , 1)
# (cafe , 1)
# (BERTHOLLET , 1)
# (Rouge , 1)
# (タリーズコーヒー , 1)
# (菓子 , 1)
# (ハーモニー , 1)
# (アグリ , 1)
# (ワンオーワン , 1)
# (コーディネーター , 1)
# (ドナー , 1)
# (整理 , 1)
# (普及 , 1)
# (啓発 , 1)
# (バンク , 1)
# (8655 , 1)
# (保有 , 1)
# (検査 , 1)
# (技師 , 1)
# (実務 , 1)
# (35 , 1)
# (刺激 , 1)
# (54471 , 1)
# (コリアン , 1)
# (レンゲ , 1)
# (出典 , 1)
# (Logo , 1)
# (tabelog , 1)
# (森の里 , 1)
# (備え付け , 1)
# (ラー油 , 1)
# (ニンニク , 1)
# (トッピング , 1)
# (ツウ , 1)
# (改装 , 1)
# (種類 , 1)
# (特定 , 1)
# (フルタイム , 1)
# (薬剤師 , 1)
# (2694 , 1)
# (2015 , 1)
# (フルーレ , 1)
# (エペ , 1)
# (サーブル , 1)
# (About , 1)
# (Results , 1)
# (Schedules , 1)
# (Newcomers , 1)
# (Members , 1)
# (OG , 1)
# (Link , 1)
# (Blog , 1)
# (ホリデー , 1)
# (在宅 , 1)
# (スマート , 1)
# (子弟 , 1)
# (減免 , 1)
# (愛知教育大学 , 1)
# (三重大学 , 1)
# (滋賀大学 , 1)
# (滋賀県立大学 , 1)
# (Illustrator , 1)
# (Photoshop , 1)
# (グラフィックデザイナー , 1)
# (p , 1)
# (グラフィック , 1)
# (地域 , 1)
# (施策 , 1)
# (なか , 1)
# (提言 , 1)
# (共有 , 1)
# (意義 , 1)
# (本書 , 1)
# (構成 , 1)
# (所得 , 1)
# (味の素 , 1)
# (早大 , 1)
# (橋本 , 1)
# (療法 , 1)
# (軽井沢 , 1)
# (車中 , 1)
# (往復 , 1)
# (貴重 , 1)
# (ミーティング , 1)
# (カーリング , 1)
# (自負 , 1)
# (競技 , 1)
# (悩み , 1)
# (今季 , 1)
# (控え , 1)
# (遠征 , 1)
# (回避 , 1)
# (スタート , 1)
# (アップ , 1)
# (理念 , 1)
# (スキルアップサポート , 1)
# (白梅学園 , 1)
# (リズム , 1)
# (表現 , 1)
# (マネジメント , 1)
# (救命 , 1)
# (スペシャリスト , 1)
# (岡山大学 , 1)
# (神奈川大学 , 1)
# (関西大学 , 1)
# (九州 , 1)
# (九州工業大学 , 1)
# (京都府立大学 , 1)
# (熊本大学 , 1)
# (高知工科大学 , 1)
# (埼玉大学 , 1)
# (島根大学 , 1)
# (Hospital , 1)
# (available , 1)
# (Clinic , 1)
# (Dentaloffice , 1)
# (歯科 , 1)
# (医院 , 1)
# (設計 , 1)
# (Indeed , 1)
# (com , 1)
# (帯広 , 1)
# (室蘭 , 1)
# (商科 , 1)
# (信州 , 1)
# (札幌 , 1)
# (工科 , 1)
# (定額 , 1)
# (付記 , 1)
# (前年度 , 1)
# (34 , 1)
# (実費 , 1)
# (124 , 1)
# (?B , 1)
# (静岡理工科大学 , 1)
# (福井大学 , 1)
# (明星大学 , 1)
# (東京工科大学 , 1)
# (神奈川工科大学 , 1)
# (東京水産大学 , 1)
# (北里大学 , 1)
# (産能大学 , 1)
# (常葉 , 1)
# (立命館大学 , 1)
# (徳島文理大学 , 1)
# (富山大学 , 1)
# (立正大学 , 1)
# (愛知工業大学 , 1)
# (東海大学 , 1)
# (龍谷大学 , 1)
# (奈良 , 1)
# (山梨学院大学 , 1)
# (キユーピー , 1)
# (融資 , 1)
# (早稲田 , 1)
# (立教 , 1)
# (文化放送 , 1)
# (ナースナビ , 1)
# (優良 , 1)
# (テスト , 1)
# (給料 , 1)
# (メッセージ , 1)
# (web , 1)
# (盛りだくさん , 1)
# (コンテンツ , 1)
# (ナース , 1)
# (専科 , 1)
# (セレクト , 1)
# (841795 , 1)
# (橄欖 , 1)
# (かん , 1)
# (らん , 1)
# (旧制 , 1)
# (校章 , 1)
# (2004 , 1)
# (ルヴェソンヴェール , 1)
# (制限 , 1)
# (同様 , 1)
# (テラス , 1)
# (クラシカル , 1)
# (現代 , 1)
# (テイスト , 1)
# (評判 , 1)
# (301 , 1)
# (理由 , 1)
# (ナスコミ , 1)
# (有休 , 1)
# (ごろ , 1)
# (...( , 1)
# (残り , 1)
# (66 , 1)
# (時期 , 1)
# (ID , 1)
# (158560 , 1)
# (成蹊大学 , 1)
# (成城大学 , 1)
# (西南学院大学 , 1)
# (摂南大学 , 1)
# (大東文化大学 , 1)
# (千葉工業大学 , 1)
# (千葉商科大学 , 1)
# (中京 , 1)
# (東京経済大学 , 1)
# (シスコ , 1)
# (システムズ , 1)
# (エクスビジョン , 1)
# (高速 , 1)
# (実用 , 1)
# (母体 , 1)
# (組み込み , 1)
# (デバイス , 1)
# (ドライバー , 1)
# (Linux , 1)
# (アプリケーション , 1)
# (夏目 , 1)
# (ビル , 1)
# (活字 , 1)
# (地方 , 1)
# (公共 , 1)
# (明記 , 1)
# (日本橋 , 1)
# (二松学舎 , 1)
# (かた , 1)
# (視聴覚 , 1)
# (DVD , 1)
# (それぞれ , 1)
# (綜研 , 1)
# (向上心 , 1)
# (バリエーション , 1)
# (貴方 , 1)
# (一緒 , 1)
# (要請 , 1)
# (クライアント , 1)
# (そこ , 1)
# (満足 , 1)
# (達成 , 1)
# (違い , 1)
# (金沢 , 1)
# (スト , 1)
# (高校生 , 1)
# (088 , 1)
# (679 , 1)
# (6021 , 1)
# (Seria , 1)
# (どんぐり , 1)
# (カンタン , 1)
# (内々定 , 1)
# (OpenES , 1)
# (定着 , 1)
# (奨励 , 1)
# (IT , 1)
# (商船 , 1)
# (三重 , 1)
# (兵庫 , 1)
# (` , 1)
# (新潟大学 , 1)
# (長岡技術科学大学 , 1)
# (お茶の水女子大学 , 1)
# (大阪府立大学 , 1)
# (広島大学 , 1)
# (上智 , 1)
# (農業 , 1)
# (基金 , 1)
# (スポーツ , 1)
# (家賃 , 1)
# (男子 , 1)
# (慶応義塾大学 , 1)
# (群馬大学 , 1)
# (大分大学 , 1)
# (エレクトロン , 1)
# (東宝 , 1)
# (課長 , 1)
# (ニコル , 1)
# (水産 , 1)
# (北極 , 1)
# (技官 , 1)
# (エチオピア , 1)
# (シミ , 1)
# (山岳 , 1)
# (園長 , 1)
# (官等 , 1)
# (歴任 , 1)
# (エコツーリズム , 1)
# (／( , 1)
# (ニコル・アファン , 1)
# (狩猟 , 1)
# (青木 , 1)
# (勢多 , 1)
# (農林 , 1)
# (教諭 , 1)
# (インターン , 1)
# (人物 , 1)
# (興味 , 1)
# (関心 , 1)
# (タスク , 1)
# (それ , 1)
# (先行 , 1)
# (お待ち , 1)
# (京王 , 1)
# (製図 , 1)
# (明石工業高等専門学校 , 1)
# (現地 , 1)
# (販売 , 1)
# (近畿 , 1)
# (全域 , 1)
# (法定 , 1)
# (各個 , 1)
# (ロビー , 1)
# (エレベーター , 1)
# (入館 , 1)
# (各校 , 1)
# (関西学院 , 1)
# (5222 , 1)
# (5678 , 1)
# (甲南 , 1)
# (新潟 , 1)
# (5224 , 1)
# (8288 , 1)
# (東北 , 1)
# (2055 , 1)
# (西南 , 1)
# (名古屋工業大学 , 1)
# (北九州大学 , 1)
# (カプコン , 1)
# (ローテーション , 1)
# (実働 , 1)
# (芸術 , 1)
# (淑徳 , 1)
# (麻生 , 1)
# (北九州 , 1)
# (ＥＣＣ , 1)
# (コンピュータ , 1)
# (岩手 , 1)
# (メディア , 1)
# (ニトリ , 1)
# (東洋ゴム工業 , 1)
# (190 , 1)
# (180 , 1)
# (都市 , 1)
# (別居 , 1)
# (祝祭日 , 1)
# (52 , 1)
# (時短 , 1)
# (216 , 1)
# (大学卒 , 1)
# (211 , 1)
# (本科 , 1)
# (194 , 1)
# (報奨 , 1)
# (ステージ , 1)
# (節目 , 1)
# (鹿児島大学 , 1)
# (京都工芸繊維大学 , 1)
# (自治 , 1)
# (医科 , 1)
# (総合研究大学院大学 , 1)
# (薬科 , 1)
# (鳥取大学 , 1)
# (同志社大学 , 1)
# (長浜 , 1)
# (バイオ , 1)
# (サン , 1)
# (デリカ , 1)
# (あなた , 1)
# (コピーライター , 1)
# (シーン , 1)
# (デザイナー , 1)
# (減少 , 1)
# (北里 , 1)
# (三郎 , 1)
# (初代 , 1)
# (所長 , 1)
# (創設 , 1)
# (伝染 , 1)
# (起源 , 1)
# (がん , 1)
# (感染 , 1)
# (免疫 , 1)
# (血液 , 1)
# (治療 , 1)
# (オペ , 1)
# (Summer , 1)
# (Seminar , 1)
# (プロジェク , 1)
# (本稿 , 1)
# (航空 , 1)
# (宇宙 , 1)
# (;M9 , 1)
# (ただ , 1)
# (ミーハー , 1)
# (カツ , 1)
# (品切れ , 1)
# (日時 , 1)
# (44 , 1)
# (遺伝 , 1)
# (若手 , 1)
# (付き , 1)
# (判明 , 1)
# (話し合い , 1)
# (泰三 , 1)
# (結論 , 1)
# (同期 , 1)
# (意地悪 , 1)
# (真剣 , 1)
# (部下 , 1)
# (心配 , 1)
# (.. , 1)
# (来社 , 1)
# (離島 , 1)
# (山間 , 1)
# (交換 , 1)
# (設備 , 1)
# (翌日 , 1)
# (仮設 , 1)
# (浄水 , 1)
# (現場 , 1)
# (上水道 , 1)
# (皆様 , 1)
# (お世話 , 1)
# (中番 , 1)
# (遅番 , 1)
# (010 , 1)
# (感謝 , 1)
# (構内 , 1)
# (南北 , 1)
# (製造 , 1)
# (9H9 , 1)
# (メーデー , 1)
# (明治大学 , 1)
# (学習 , 1)
#  , 1)
# (銀座 , 1)
# (扱い , 1)
# (生命 , 1)
# (ラフォーレ , 1)
# (倶楽部 , 1)
# (JTB , 1)
# (新入 , 1)
# (中堅 , 1)
# (派遣 , 1)

# %%
with open('mayfes/text_data/todai_kyuka_verb.txt','w') as f:
    for k, v in sorted(verb_dic.items(), key=lambda x:x[1], reverse=True):
#         print("({0} , {1})".format(k, v)) # ==> 5 1, 2 3, 1 4の順番．valueで昇順の並び
        f.write("({0} , {1})\n".format(k, v))
# Out:
# (する , 170)
# (あり , 65)
# (なる , 35)
# (ある , 33)
# (ください , 27)
# (いる , 26)
# (いう , 25)
# (定める , 24)
# (できる , 24)
# (なり , 19)
# (見る , 18)
# (でき , 16)
# (おり , 15)
# (行う , 14)
# (れる , 14)
# (役に立つ , 14)
# (いたし , 13)
# (なっ , 13)
# (行っ , 10)
# (いただき , 10)
# (基づき , 8)
# (有する , 8)
# (除く , 7)
# (致し , 7)
# (られ , 6)
# (られる , 6)
# (係る , 6)
# (受け , 6)
# (伴い , 5)
# (探し , 5)
# (持越し , 5)
# (持ち , 5)
# (基づく , 4)
# (異なる , 4)
# (応じ , 4)
# (認め , 4)
# (続ける , 4)
# (行わ , 4)
# (よる , 4)
# (伴う , 4)
# (行い , 4)
# (用い , 4)
# (考え , 4)
# (掲げる , 4)
# (役立つ , 4)
# (勧め , 4)
# (食べ , 4)
# (働き , 4)
# (達する , 3)
# (いただく , 3)
# (超える , 3)
# (伝える , 3)
# (ござい , 3)
# (下さい , 3)
# (取り揃え , 3)
# (取り入れ , 3)
# (過ごせる , 3)
# (願い , 3)
# (求め , 3)
# (いただい , 3)
# (与える , 3)
# (あわせ , 3)
# (異なり , 3)
# (含む , 3)
# (持つ , 3)
# (みなし , 3)
# (取り , 3)
# (おそう , 3)
# (誇る , 3)
# (なら , 2)
# (あっ , 2)
# (申込み , 2)
# (取組み , 2)
# (かかわら , 2)
# (おく , 2)
# (差し引い , 2)
# (すすめる , 2)
# (ゆく , 2)
# (知っ , 2)
# (いただけ , 2)
# (向け , 2)
# (組み合わせ , 2)
# (戻る , 2)
# (思っ , 2)
# (くれ , 2)
# (まとめ , 2)
# (決め , 2)
# (0 , 2)
# (働く , 2)
# (呼ば , 2)
# (取れ , 2)
# (使っ , 2)
# (着け , 2)
# (わかり , 2)
# (ふまえ , 2)
# (もっ , 2)
# (育つ , 2)
# (目指す , 2)
# (開き , 2)
# (備え , 2)
# (抱え込ま , 2)
# (伝え , 2)
# (強め , 2)
# (取れる , 2)
# (取る , 2)
# (とら , 1)
# (設け , 1)
# (支える , 1)
# (つき , 1)
# (認める , 1)
# (かかる , 1)
# (満た , 1)
# (限る , 1)
# (付す , 1)
# (預かり , 1)
# (基づい , 1)
# (持っ , 1)
# (取り組み , 1)
# (定め , 1)
# (ともなう , 1)
# (変わり , 1)
# (始まる , 1)
# (含め , 1)
# (除き , 1)
# (過ぎる , 1)
# (扱わ , 1)
# (義務づけ , 1)
# (てる , 1)
# (受け入れる , 1)
# (満たす , 1)
# (生きる , 1)
# (生まれ , 1)
# (楽しみ , 1)
# (いただか , 1)
# (過ぎ , 1)
# (受け付け , 1)
# (申し出 , 1)
# (生ずる , 1)
# (施し , 1)
# (優れ , 1)
# (扱える , 1)
# (置き換え , 1)
# (有し , 1)
# (頂く , 1)
# (満たし , 1)
# (関する , 1)
# (おかけいたし , 1)
# (伺い , 1)
# (限ら , 1)
# (なさ , 1)
# (示さ , 1)
# (異なっ , 1)
# (示し , 1)
# (調べ , 1)
# (割振 , 1)
# (おけ , 1)
# (了する , 1)
# (しく , 1)
# (やめ , 1)
# (成り , 1)
# (付け , 1)
# (休む , 1)
# (繰り越す , 1)
# (せる , 1)
# (役に立て , 1)
# (願っ , 1)
# (踏まえ , 1)
# (かかっ , 1)
# (届き , 1)
# (つい , 1)
# (飲み , 1)
# (挽い , 1)
# (観る , 1)
# (負け , 1)
# (買っ , 1)
# (あれ , 1)
# (教え , 1)
# (学べる , 1)
# (まいり , 1)
# (離れ , 1)
# (揃い , 1)
# (回っ , 1)
# (おい , 1)
# (併せ , 1)
# (積ん , 1)
# (もらい , 1)
# (すれ , 1)
# (始める , 1)
# (進む , 1)
# (しまう , 1)
# (高める , 1)
# (取り組ん , 1)
# (使う , 1)
# (知る , 1)
# (触れる , 1)
# (増やし , 1)
# (手伝う , 1)
# (おら , 1)
# (働ける , 1)
# (学べ , 1)
# (出し , 1)
# (雇い , 1)
# (しよ , 1)
# (鳴らし , 1)
# (落ち着い , 1)
# (伴っ , 1)
# (生み出す , 1)
# (目覚め , 1)
# (もらえる , 1)
# (買い求め , 1)
# (選ん , 1)
# (見える , 1)
# (いすれ , 1)
# (申し込み , 1)
# (関わっ , 1)
# (出さ , 1)
# (続い , 1)
# (起こり , 1)
# (` , 1)
# (持ち替え , 1)
# (させ , 1)
# (学ぶ , 1)
# (問い , 1)
# (突っ込み , 1)
# (おろし , 1)
# (行か , 1)
# (みよ , 1)
# (分かれ , 1)
# (指す , 1)
# (頂き , 1)
# (論じ , 1)
# (図る , 1)
# (話し合う , 1)
# (回り , 1)
# (頂け , 1)
# (支払わ , 1)
# (分かる , 1)
# (呼ん , 1)
# (使わ , 1)
# (読める , 1)
# (思い , 1)
# (勤め , 1)
# (目指し , 1)
# (あふれる , 1)
# (応える , 1)
# (いき , 1)
# (休み , 1)
# (話せ , 1)
# (生かせる , 1)
# (求める , 1)
# (決まっ , 1)
# (有り , 1)
# (探す , 1)
# (見つかり , 1)
# (入れ , 1)
# (得る , 1)
# (聞い , 1)
# (やって来 , 1)
# (食べよ , 1)
# (務め , 1)
# (いかれる , 1)
# (押し切り , 1)
# (入れ替わる , 1)
# (抱える , 1)
# (取り巻く , 1)
# (見込み , 1)

# %%
with open('mayfes/text_data/todai_kyuka_adjec.txt','w') as f:
    for k, v in sorted(adjective_dic.items(), key=lambda x:x[1], reverse=True):
#         print("({0} , {1})".format(k, v)) # ==> 5 1, 2 3, 1 4の順番．valueで昇順の並び
        f.write("({0} , {1})\n".format(k, v))
# Out:
# (ない , 7)
# (なし , 7)
# (いい , 4)
# (多い , 3)
# (望ましい , 2)
# (詳しく , 2)
# (新しい , 2)
# (難しく , 2)
# (にくい , 1)
# (無い , 1)
# (怪しい , 1)
# (高い , 1)
# (低い , 1)
# (よい , 1)
# (やすく , 1)
# (ひろき , 1)
# (深く , 1)
# (くろ , 1)
# (良く , 1)
# (大きく , 1)
# (多く , 1)
# (なく , 1)
# (気持ち良い , 1)
# (幅広く , 1)
# (強く , 1)

# %%
with open('mayfes/text_data/todai_kyuka_adv.txt','w') as f:
    for k, v in sorted(adverb_dic.items(), key=lambda x:x[1], reverse=True):
#         print("({0} , {1})".format(k, v)) # ==> 5 1, 2 3, 1 4の順番．valueで昇順の並び
        f.write("({0} , {1})\n".format(k, v))
# Out:
# (よろしく , 4)
# (特に , 4)
# (何かと , 3)
# (あくまで , 3)
# (もう少し , 3)
# (悪しからず , 3)
# (これから , 3)
# (引き続き , 2)
# (さらに , 2)
# (当然 , 2)
# (ぜひ , 2)
# (ゆったり , 2)
# (もちろん , 2)
# (あらためて , 2)
# (どう , 2)
# (別に , 1)
# (予め , 1)
# (とても , 1)
# (いまだ , 1)
# (きちんと , 1)
# (必ず , 1)
# (くれぐれも , 1)
# (実際 , 1)
# (あらかじめ , 1)
# (引続き , 1)
# (少し , 1)
# (順次 , 1)
# (極めて , 1)
# (宜しく , 1)
# (更に , 1)
# (あまり , 1)
# (キチン , 1)
# (すぐ , 1)
# (しっかり , 1)
# (よく , 1)
# (次に , 1)
# (何卒 , 1)
# (一体 , 1)
# (同時に , 1)
# (たっぷり , 1)
# (もう , 1)
# (なぜ , 1)
# (きっと , 1)
# (こう , 1)
# (じっくり , 1)
# (ぴったり , 1)
# (しばらく , 1)
# (まったく , 1)
