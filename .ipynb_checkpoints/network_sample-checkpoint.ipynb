# %%
import pandas as pd

# %%
def process_text(filename):
    texts = []
    with open('./mayfes/text_data/'+filename, 'r') as f:
        for line in f:
            texts.append(line[1:-2].replace(' ', '').split(','))
    df = pd.DataFrame(texts)
    if 2 in df.columns:
        drop_index = df.loc[df[2].notnull(), :].index
        df = df.drop(index=drop_index).reset_index(drop=True).rename(columns={0:'word', 1:filename.split('.')[0]})
    df = df.drop(index=df.loc[df['word'].str.match(r'^[a-zA-Z0-9_]+$')].index).reset_index(drop=True)
    df = df.drop(index=df.loc[df['word'].str.match(r'^[!-/:-@[-`{-~]+$')].index).reset_index(drop=True)
    return df.dropna(axis=1).reset_index(drop=True)
def make_univ_dfs(univ_name):
    types = ['noun']
    filenames = map(lambda tp: univ_name + '_' + tp + '.txt', types)
    dfs = list(map(process_text, filenames))
    return dict(zip(types, dfs))

# %%
import numpy as np

# %%
ut_dict = make_univ_dfs('todai')
wa_dict = make_univ_dfs('waseda')
me_dict = make_univ_dfs('meiji')
ky_dict = make_univ_dfs('kyodai')
full_df = ut_dict['noun'].merge(wa_dict['noun'], on='word') .merge(me_dict['noun'], on='word').merge(ky_dict['noun'], on='word')
full_df['count'] = full_df['todai_noun'].astype(int) + full_df['waseda_noun'].astype(int) + full_df['meiji_noun'].astype(int) + full_df['kyodai_noun'].astype(int)
full_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-54e58442341a> in <module>()
# ----> 1 ut_dict = make_univ_dfs('todai')
#       2 wa_dict = make_univ_dfs('waseda')
#       3 me_dict = make_univ_dfs('meiji')
#       4 ky_dict = make_univ_dfs('kyodai')
#       5 full_df = ut_dict['noun'].merge(wa_dict['noun'], on='word') .merge(me_dict['noun'], on='word').merge(ky_dict['noun'], on='word')
#
# <ipython-input-18-0dd1c9b05ce0> in make_univ_dfs(univ_name)
#      14     types = ['noun']
#      15     filenames = map(lambda tp: univ_name + '_' + tp + '.txt', types)
# ---> 16     dfs = list(map(process_text, filenames))
#      17     return dict(zip(types, dfs))
#
# <ipython-input-18-0dd1c9b05ce0> in process_text(filename)
#       7     if 2 in df.columns:
#       8         drop_index = df.loc[df[2].notnull(), :].index
# ----> 9         df = df.drop(index=drop_index).reset_index(drop=True).rename(columns={0:'word', 1:filename.split('.')[0]})
#      10     df = df.drop(index=df.loc[df['word'].str.match(r'^[a-zA-Z0-9_]+$')].index).reset_index(drop=True)
#      11     df = df.drop(index=df.loc[df['word'].str.match(r'^[!-/:-@[-`{-~]+$')].index).reset_index(drop=True)
#
# TypeError: drop() got an unexpected keyword argument 'index'

# %%
import functools
ut_words = list(map(lambda l: tuple(l), ut_dict['noun'].values))
wa_words = list(map(lambda l: tuple(l), wa_dict['noun'].values))
ky_words = list(map(lambda l: tuple(l), ky_dict['noun'].values))
me_words = list(map(lambda l: tuple(l), me_dict['noun'].values))
def a(univ_word):
    return [univ_word[0]] * int(univ_word[1])
ut_words = functools.reduce(lambda l1,l2: l1+l2, map(a, ut_words))
wa_words = functools.reduce(lambda l1,l2: l1+l2, map(a, wa_words))
ky_words = functools.reduce(lambda l1,l2: l1+l2, map(a, ky_words))
me_words = functools.reduce(lambda l1,l2: l1+l2, map(a, me_words))
full_words = [ut_words, wa_words, ky_words, me_words]

# %%
from gensim import corpora
from gensim import models
from operator import itemgetter
import functools
def ranking_by_tfidf(full_texts, target_words_list, n_extract=None):
    """
    tfidfによる対象の文書の単語ランキングを出力する。
    variables
    ----------
    full_texts: list(list(str))
    全文書の単語のlistが含まれているlist
    target_words_list: list(str)
    対象の文書の単語のlist
    n_extract: int
    第何位までランキングを出力するか？
    """
    dictionary = corpora.Dictionary(full_texts)
    id2token = {v: k for k, v in dictionary.token2id.items()}
    full_corpus = map(dictionary.doc2bow, full_texts)
    target_corpus = map(dictionary.doc2bow, [target_words_list])
    tfidf_model = models.TfidfModel(full_corpus)

    if n_extract is None:
        ranking_by_id = sorted(list(tfidf_model[target_corpus])[0], key=itemgetter(1), reverse=True)
    else:
        ranking_by_id = sorted(list(tfidf_model[target_corpus])[0], key=itemgetter(1), reverse=True)[0:n_extract]

    map_ranking = map(functools.partial(lambda id2token, tp: ((id2token[tp[0]], tp[1])), id2token), ranking_by_id)

    return list(map_ranking)

def ranking2df(ranking, column_names):
    return pd.DataFrame(list(zip(*ranking)) ,index=column_names).T

# %%
me_top_tfidf = ranking_by_tfidf(full_words, me_words)[0:10]
me_top_tfidf
# Out:
# [('支部', 0.31634665670994894),
#  ('駿河台', 0.1953905820855567),
#  ('校友', 0.1721297985039428),
#  ('厚吉', 0.16747764178762004),
#  ('神田駿河台', 0.16747764178762004),
#  ('明治大学', 0.15817332835497447),
#  ('生田', 0.15817332835497447),
#  ('Թ\x7f', 0.14421685820600613),
#  ('\u05f8\x7f', 0.1302603880570378),
#  ('和泉', 0.1302603880570378)]

# %%
import networkx as nx
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
#ネットワーク作成
def network(univ_name, top_tfidf, k):
    G = nx.Graph()
    nodes = []

    for tp in top_tfidf:
        nodes.append((univ_name, {'tfidf':1}))
        nodes.append((tp[0], {'tfidf':tp[1]}))
    G.add_nodes_from(nodes)
    for tp in top_tfidf:
        G.add_edge(univ_name, tp[0], weight= 1)
    #ネットワーク図描画
    plt.figure(figsize=(15,15))
    pos = nx.spring_layout(G,k=k)
    # node_size = [ d["count]*20 for (n,d) in G.nodes(data=True)]
    node_size = [ d["tfidf"]*100000 for (n,d) in G.nodes(data=True)]
    edge_width = [ d['weight']*20 for (u,v,d) in G.edges(data=True)]
    nx.draw_networkx_nodes(G, pos, node_color="r",alpha=0.6, node_size=node_size)
    nx.draw_networkx_labels(G, pos, font_family="IPAGothic", fontsize=10)
    nx.draw_networkx_edges(G, pos, alpha=0.4, edge_color='C', width=edge_width)

    plt.axis("off")
    plt.show()

# %%
plt.rcParams['font.family'] = 'IPAPGothic'

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/home/bearshu11/.anyenv/envs/pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
network('明治大学',ranking_by_tfidf(full_words, me_words)[0:10], 0.25)
# Out:
# /home/bearshu11/.anyenv/envs/pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['IPAGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/bearshu11/.anyenv/envs/pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['IPAPGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
full_corpus = list(map(lambda l: tuple(l), full_df[['word', 'count']].values))
full_words = full_df['word'].values
dictionary = corpora.Dictionary([full_words])
token2id = {k: v for k, v in dictionary.token2id.items()}
id2token = {v: k for k, v in dictionary.token2id.items()}
token2id
# Out:
# {'(@': 0,
#  ').': 1,
#  ');': 2,
#  ')、': 3,
#  ')。': 4,
#  '...': 5,
#  '00': 6,
#  '000': 7,
#  '01': 8,
#  '02': 9,
#  '03': 10,
#  '04': 11,
#  '05': 12,
#  '06': 13,
#  '07': 14,
#  '08': 15,
#  '09': 16,
#  '10': 17,
#  '100': 18,
#  '1000': 19,
#  '11': 20,
#  '12': 21,
#  '13': 22,
#  '14': 23,
#  '15': 24,
#  '16': 25,
#  '17': 26,
#  '18': 27,
#  '19': 28,
#  '1985': 29,
#  '1995': 30,
#  '20': 31,
#  '200': 32,
#  '2003': 33,
#  '2005': 34,
#  '2007': 35,
#  '2008': 36,
#  '2009': 37,
#  '2012': 38,
#  '2013': 39,
#  '2014': 40,
#  '2015': 41,
#  '2016': 42,
#  '2017': 43,
#  '2018': 44,
#  '21': 45,
#  '22': 46,
#  '23': 47,
#  '24': 48,
#  '25': 49,
#  '26': 50,
#  '27': 51,
#  '28': 52,
#  '29': 53,
#  '30': 54,
#  '300': 55,
#  '31': 56,
#  '33': 57,
#  '40': 58,
#  '45': 59,
#  '50': 60,
#  '500': 61,
#  '60': 62,
#  '72': 63,
#  '75': 64,
#  '80': 65,
#  '90': 66,
#  '://': 67,
#  'CD': 68,
#  'Club': 69,
#  'FAX': 70,
#  'Facebook': 71,
#  'Google': 72,
#  'HOME': 73,
#  'HP': 74,
#  'JR': 75,
#  'Japan': 76,
#  'LIFULL': 77,
#  'Lincun': 78,
#  'MB': 79,
#  'Map': 80,
#  'News': 81,
#  'OB': 82,
#  'PC': 83,
#  'SNS': 84,
#  'Science': 85,
#  'System': 86,
#  'TEL': 87,
#  'TOP': 88,
#  'Tweets': 89,
#  'University': 90,
#  'Web': 91,
#  '].': 92,
#  'ac': 93,
#  'and': 94,
#  'are': 95,
#  'co': 96,
#  'com': 97,
#  'for': 98,
#  'from': 99,
#  'https': 100,
#  'in': 101,
#  'jp': 102,
#  'of': 103,
#  'svg': 104,
#  'the': 105,
#  'www': 106,
#  'あなた': 107,
#  'いつ': 108,
#  'いま': 109,
#  'うえ': 110,
#  'おすすめ': 111,
#  'お待ち': 112,
#  'お知らせ': 113,
#  'お越し': 114,
#  'お送り': 115,
#  'お願い': 116,
#  'がく': 117,
#  'ここ': 118,
#  'こちら': 119,
#  'こと': 120,
#  'これ': 121,
#  'これら': 122,
#  'ごと': 123,
#  'ご覧': 124,
#  'さまざま': 125,
#  'さん': 126,
#  'すべて': 127,
#  'その他': 128,
#  'その後': 129,
#  'それ': 130,
#  'それぞれ': 131,
#  'それら': 132,
#  'たち': 133,
#  'ため': 134,
#  'だい': 135,
#  'つながり': 136,
#  'づくり': 137,
#  'とおり': 138,
#  'とき': 139,
#  'どこ': 140,
#  'なか': 141,
#  'はじめ': 142,
#  'ほか': 143,
#  'みなさま': 144,
#  'もと': 145,
#  'もの': 146,
#  'よう': 147,
#  'アカウント': 148,
#  'アクセス': 149,
#  'アジア': 150,
#  'アップ': 151,
#  'アパート': 152,
#  'アンケート': 153,
#  'イノベーション': 154,
#  'イベント': 155,
#  'ウィキペディア': 156,
#  'ウェブサイト': 157,
#  'エネルギー': 158,
#  'エリア': 159,
#  'オンライン': 160,
#  'オーケストラ': 161,
#  'オープン': 162,
#  'カウンター': 163,
#  'カテゴリ': 164,
#  'カード': 165,
#  'キャリア': 166,
#  'キャンパス': 167,
#  'クラス': 168,
#  'クラブ': 169,
#  'クリック': 170,
#  'グループ': 171,
#  'グローバル': 172,
#  'ゲスト': 173,
#  'コミュニケーション': 174,
#  'コレクション': 175,
#  'コンテンツ': 176,
#  'コース': 177,
#  'コーナー': 178,
#  'サイエンス': 179,
#  'サイト': 180,
#  'サッカー': 181,
#  'サポート': 182,
#  'サークル': 183,
#  'サービス': 184,
#  'システム': 185,
#  'シンポジウム': 186,
#  'スケジュール': 187,
#  'スタッフ': 188,
#  'スタート': 189,
#  'スペース': 190,
#  'スポーツ': 191,
#  'スーパー': 192,
#  'セキュリティ': 193,
#  'セミナー': 194,
#  'センター': 195,
#  'タイトル': 196,
#  'チェック': 197,
#  'チーム': 198,
#  'ツアー': 199,
#  'テスト': 200,
#  'テレビ': 201,
#  'テーマ': 202,
#  'デザイン': 203,
#  'データ': 204,
#  'トップ': 205,
#  'ニュース': 206,
#  'ネットワーク': 207,
#  'バス': 208,
#  'バス停': 209,
#  'パソコン': 210,
#  'パワー': 211,
#  'パンフ': 212,
#  'パンフレット': 213,
#  'ビジネス': 214,
#  'フィールド': 215,
#  'フランス': 216,
#  'フリー': 217,
#  'ブック': 218,
#  'ブログ': 219,
#  'プログラム': 220,
#  'プロジェクト': 221,
#  'ページ': 222,
#  'ホテル': 223,
#  'ホームズ': 224,
#  'ホームページ': 225,
#  'ホール': 226,
#  'ポイント': 227,
#  'ポリシー': 228,
#  'マップ': 229,
#  'マネジメント': 230,
#  'マンション': 231,
#  'マーク': 232,
#  'ミッション': 233,
#  'メイン': 234,
#  'メッセージ': 235,
#  'メディア': 236,
#  'メンバー': 237,
#  'メール': 238,
#  'ライフル': 239,
#  'ランキング': 240,
#  'リリース': 241,
#  'リンク': 242,
#  'リーグ': 243,
#  'リーダー': 244,
#  'ルーム': 245,
#  'ローン': 246,
#  '一つ': 247,
#  '一番': 248,
#  '一般': 249,
#  '一覧': 250,
#  '一貫': 251,
#  '一部': 252,
#  '三菱': 253,
#  '下記': 254,
#  '不動産': 255,
#  '不要': 256,
#  '世代': 257,
#  '世界': 258,
#  '世紀': 259,
#  '両立': 260,
#  '中国': 261,
#  '中央': 262,
#  '中学校': 263,
#  '中心': 264,
#  '主体': 265,
#  '主要': 266,
#  '了承': 267,
#  '予備校': 268,
#  '予定': 269,
#  '予約': 270,
#  '事務': 271,
#  '事務所': 272,
#  '事業': 273,
#  '交流': 274,
#  '交通': 275,
#  '京都': 276,
#  '人工': 277,
#  '人数': 278,
#  '人材': 279,
#  '人気': 280,
#  '人物': 281,
#  '人間': 282,
#  '今年': 283,
#  '今後': 284,
#  '今日': 285,
#  '仕事': 286,
#  '仕組み': 287,
#  '代表': 288,
#  '以上': 289,
#  '以下': 290,
#  '以外': 291,
#  '以来': 292,
#  '企業': 293,
#  '企画': 294,
#  '休み': 295,
#  '休業': 296,
#  '会員': 297,
#  '会場': 298,
#  '会社': 299,
#  '会計': 300,
#  '会議': 301,
#  '会長': 302,
#  '会館': 303,
#  '伝統': 304,
#  '住まい': 305,
#  '住宅': 306,
#  '住所': 307,
#  '体制': 308,
#  '体育': 309,
#  '体験': 310,
#  '作品': 311,
#  '作成': 312,
#  '使用': 313,
#  '依頼': 314,
#  '価格': 315,
#  '便利': 316,
#  '促進': 317,
#  '保護': 318,
#  '修了': 319,
#  '個人': 320,
#  '個別': 321,
#  '倍率': 322,
#  '偏差': 323,
#  '健康': 324,
#  '備考': 325,
#  '優勝': 326,
#  '優秀': 327,
#  '充実': 328,
#  '先生': 329,
#  '先端': 330,
#  '先輩': 331,
#  '入会': 332,
#  '入力': 333,
#  '入学': 334,
#  '入試': 335,
#  '入部': 336,
#  '全体': 337,
#  '全国': 338,
#  '全学': 339,
#  '公共': 340,
#  '公園': 341,
#  '公式': 342,
#  '公開': 343,
#  '共同': 344,
#  '共有': 345,
#  '共通': 346,
#  '内容': 347,
#  '内部': 348,
#  '写真': 349,
#  '処理': 350,
#  '出典': 351,
#  '出張': 352,
#  '出版': 353,
#  '出身': 354,
#  '出願': 355,
#  '分野': 356,
#  '刊行': 357,
#  '初期': 358,
#  '利用': 359,
#  '制度': 360,
#  '制御': 361,
#  '前身': 362,
#  '創立': 363,
#  '創設': 364,
#  '創造': 365,
#  '創部': 366,
#  '加盟': 367,
#  '勉強': 368,
#  '動画': 369,
#  '勝利': 370,
#  '募集': 371,
#  '勤務': 372,
#  '医学': 373,
#  '医学部': 374,
#  '医療': 375,
#  '医科': 376,
#  '千代田': 377,
#  '午後': 378,
#  '卒業': 379,
#  '卒業生': 380,
#  '協力': 381,
#  '協定': 382,
#  '協議': 383,
#  '博士': 384,
#  '博物館': 385,
#  '原則': 386,
#  '参加': 387,
#  '参照': 388,
#  '参画': 389,
#  '参考': 390,
#  '取り扱い': 391,
#  '取り組み': 392,
#  '取得': 393,
#  '取材': 394,
#  '取締役': 395,
#  '受付': 396,
#  '受賞': 397,
#  '受験': 398,
#  '受験生': 399,
#  '口コミ': 400,
#  '可能': 401,
#  '号館': 402,
#  '各種': 403,
#  '合格': 404,
#  '合計': 405,
#  '名称': 406,
#  '向け': 407,
#  '向上': 408,
#  '周年': 409,
#  '周辺': 410,
#  '品質': 411,
#  '哲学': 412,
#  '商品': 413,
#  '問い合わせ': 414,
#  '問合せ': 415,
#  '問題': 416,
#  '営利': 417,
#  '営業': 418,
#  '団体': 419,
#  '困難': 420,
#  '図書': 421,
#  '図書館': 422,
#  '国内': 423,
#  '国立': 424,
#  '国際': 425,
#  '土地': 426,
#  '在学': 427,
#  '在校生': 428,
#  '在籍': 429,
#  '地下鉄': 430,
#  '地元': 431,
#  '地図': 432,
#  '地域': 433,
#  '地理': 434,
#  '基幹': 435,
#  '基本': 436,
#  '基盤': 437,
#  '基礎': 438,
#  '基金': 439,
#  '報告': 440,
#  '場合': 441,
#  '場所': 442,
#  '変化': 443,
#  '変更': 444,
#  '外国': 445,
#  '外部': 446,
#  '多く': 447,
#  '多数': 448,
#  '多様': 449,
#  '大会': 450,
#  '大学': 451,
#  '大学生': 452,
#  '大学院': 453,
#  '大学院生': 454,
#  '契約': 455,
#  '奨励': 456,
#  '奨学': 457,
#  '女子': 458,
#  '女性': 459,
#  '委員': 460,
#  '存在': 461,
#  '学び': 462,
#  '学会': 463,
#  '学位': 464,
#  '学内': 465,
#  '学力': 466,
#  '学問': 467,
#  '学園': 468,
#  '学外': 469,
#  '学校': 470,
#  '学歴': 471,
#  '学生': 472,
#  '学科': 473,
#  '学習': 474,
#  '学術': 475,
#  '学費': 476,
#  '学部': 477,
#  '学長': 478,
#  '学院': 479,
#  '学際': 480,
#  '安全': 481,
#  '安心': 482,
#  '定員': 483,
#  '定期': 484,
#  '実施': 485,
#  '実現': 486,
#  '実績': 487,
#  '実践': 488,
#  '家族': 489,
#  '寄付': 490,
#  '対応': 491,
#  '対象': 492,
#  '専修': 493,
#  '専攻': 494,
#  '専用': 495,
#  '専門': 496,
#  '導入': 497,
#  '就職': 498,
#  '届け': 499,
#  '展示': 500,
#  '展開': 501,
#  '履修': 502,
#  '山本': 503,
#  '川上': 504,
#  '工学': 505,
#  '工学部': 506,
#  '市民': 507,
#  '希望': 508,
#  '平和': 509,
#  '平成': 510,
#  '平日': 511,
#  '年度': 512,
#  '年次': 513,
#  '年間': 514,
#  '広告': 515,
#  '広報': 516,
#  '店舗': 517,
#  '建築': 518,
#  '強化': 519,
#  '当初': 520,
#  '当日': 521,
#  '当時': 522,
#  '形成': 523,
#  '影響': 524,
#  '役割': 525,
#  '役員': 526,
#  '後期': 527,
#  '徒歩': 528,
#  '得点': 529,
#  '心配': 530,
#  '必要': 531,
#  '応援': 532,
#  '応用': 533,
#  '情報': 534,
#  '慶應義塾': 535,
#  '成果': 536,
#  '戦略': 537,
#  '所在': 538,
#  '所在地': 539,
#  '所属': 540,
#  '手数料': 541,
#  '手続き': 542,
#  '技術': 543,
#  '担当': 544,
#  '拠点': 545,
#  '指定': 546,
#  '指導': 547,
#  '挨拶': 548,
#  '振興': 549,
#  '授業': 550,
#  '採用': 551,
#  '推薦': 552,
#  '推進': 553,
#  '掲載': 554,
#  '提供': 555,
#  '提携': 556,
#  '携帯': 557,
#  '撮影': 558,
#  '支払い': 559,
#  '支援': 560,
#  '改革': 561,
#  '放送': 562,
#  '政府': 563,
#  '政策': 564,
#  '教員': 565,
#  '教室': 566,
#  '教授': 567,
#  '教材': 568,
#  '教職員': 569,
#  '教育': 570,
#  '数理': 571,
#  '文化': 572,
#  '文学': 573,
#  '文学部': 574,
#  '文献': 575,
#  '文部': 576,
#  '料金': 577,
#  '新た': 578,
#  '新入生': 579,
#  '新着': 580,
#  '新築': 581,
#  '新規': 582,
#  '方々': 583,
#  '方式': 584,
#  '方法': 585,
#  '方針': 586,
#  '施設': 587,
#  '旅行': 588,
#  '日々': 589,
#  '日時': 590,
#  '日曜日': 591,
#  '日本': 592,
#  '日本語': 593,
#  '日程': 594,
#  '明治': 595,
#  '映像': 596,
#  '春季': 597,
#  '昭和': 598,
#  '是非': 599,
#  '時代': 600,
#  '時間': 601,
#  '普及': 602,
#  '更新': 603,
#  '書店': 604,
#  '書籍': 605,
#  '最大': 606,
#  '最新': 607,
#  '最終': 608,
#  '月曜日': 609,
#  '期待': 610,
#  '期間': 611,
#  '未来': 612,
#  '未満': 613,
#  '本学': 614,
#  '本格': 615,
#  '本部': 616,
#  '材料': 617,
#  '条件': 618,
#  '東京': 619,
#  '東洋': 620,
#  '株式会社': 621,
#  '案内': 622,
#  '検索': 623,
#  '検討': 624,
#  '業務': 625,
#  '業績': 626,
#  '概要': 627,
#  '概観': 628,
#  '構想': 629,
#  '構成': 630,
#  '構造': 631,
#  '様々': 632,
#  '横浜': 633,
#  '機会': 634,
#  '機構': 635,
#  '機能': 636,
#  '機関': 637,
#  '次世代': 638,
#  '正式': 639,
#  '歴代': 640,
#  '歴史': 641,
#  '毎年': 642,
#  '比較': 643,
#  '気軽': 644,
#  '求人': 645,
#  '決定': 646,
#  '決済': 647,
#  '沿革': 648,
#  '法人': 649,
#  '法学': 650,
#  '法学部': 651,
#  '法律': 652,
#  '法科': 653,
#  '注意': 654,
#  '活動': 655,
#  '活用': 656,
#  '活躍': 657,
#  '派遣': 658,
#  '海外': 659,
#  '満載': 660,
#  '演奏': 661,
#  '演習': 662,
#  '点検': 663,
#  '無料': 664,
#  '物件': 665,
#  '特典': 666,
#  '特別': 667,
#  '特定': 668,
#  '特徴': 669,
#  '特色': 670,
#  '状況': 671,
#  '現代': 672,
#  '現在': 673,
#  '現役': 674,
#  '理事': 675,
#  '理学': 676,
#  '理工': 677,
#  '理念': 678,
#  '理科': 679,
#  '理解': 680,
#  '環境': 681,
#  '生命': 682,
#  '生活': 683,
#  '産学': 684,
#  '産業': 685,
#  '用意': 686,
#  '申し込み': 687,
#  '申請': 688,
#  '申込': 689,
#  '男子': 690,
#  '画像': 691,
#  '留学': 692,
#  '留学生': 693,
#  '略称': 694,
#  '番地': 695,
#  '番組': 696,
#  '病院': 697,
#  '発信': 698,
#  '発売': 699,
#  '発展': 700,
#  '発行': 701,
#  '発表': 702,
#  '発見': 703,
#  '発足': 704,
#  '登録': 705,
#  '皆さま': 706,
#  '皆さん': 707,
#  '皆様': 708,
#  '監督': 709,
#  '目標': 710,
#  '目次': 711,
#  '目的': 712,
#  '相互': 713,
#  '相談': 714,
#  '知的': 715,
#  '知能': 716,
#  '知識': 717,
#  '短大': 718,
#  '研究': 719,
#  '研究所': 720,
#  '確認': 721,
#  '社会': 722,
#  '祝日': 723,
#  '私立': 724,
#  '秋季': 725,
#  '科学': 726,
#  '科目': 727,
#  '程度': 728,
#  '税込': 729,
#  '種類': 730,
#  '積極': 731,
#  '空間': 732,
#  '窓口': 733,
#  '競技': 734,
#  '筑波大学': 735,
#  '管理': 736,
#  '簡単': 737,
#  '精神': 738,
#  '紹介': 739,
#  '終了': 740,
#  '組織': 741,
#  '経営': 742,
#  '経歴': 743,
#  '経済': 744,
#  '経済学部': 745,
#  '経験': 746,
#  '結果': 747,
#  '総合': 748,
#  '総長': 749,
#  '編集': 750,
#  '練習': 751,
#  '育成': 752,
#  '能力': 753,
#  '脚注': 754,
#  '自宅': 755,
#  '自己': 756,
#  '自然': 757,
#  '自由': 758,
#  '自身': 759,
#  '芸術': 760,
#  '英語': 761,
#  '著名': 762,
#  '蔵書': 763,
#  '融合': 764,
#  '行事': 765,
#  '表彰': 766,
#  '表現': 767,
#  '表示': 768,
#  '複雑': 769,
#  '要項': 770,
#  '見学': 771,
#  '規則': 772,
#  '規定': 773,
#  '規模': 774,
#  '視野': 775,
#  '観点': 776,
#  '解決': 777,
#  '解説': 778,
#  '言語': 779,
#  '計画': 780,
#  '記事': 781,
#  '記念': 782,
#  '記載': 783,
#  '設立': 784,
#  '設置': 785,
#  '設計': 786,
#  '証明': 787,
#  '評価': 788,
#  '試合': 789,
#  '試験': 790,
#  '詳細': 791,
#  '誕生': 792,
#  '説明': 793,
#  '課程': 794,
#  '課題': 795,
#  '調査': 796,
#  '請求': 797,
#  '論文': 798,
#  '講師': 799,
#  '講座': 800,
#  '講演': 801,
#  '講義': 802,
#  '講習': 803,
#  '豊か': 804,
#  '財産': 805,
#  '貢献': 806,
#  '販売': 807,
#  '貴重': 808,
#  '費用': 809,
#  '賃貸': 810,
#  '資料': 811,
#  '資格': 812,
#  '資源': 813,
#  '資産': 814,
#  '資金': 815,
#  '質問': 816,
#  '購入': 817,
#  '込み': 818,
#  '近代': 819,
#  '返還': 820,
#  '追加': 821,
#  '通信': 822,
#  '通学': 823,
#  '通常': 824,
#  '速報': 825,
#  '連合': 826,
#  '連携': 827,
#  '連盟': 828,
#  '連絡': 829,
#  '週間': 830,
#  '進学': 831,
#  '進路': 832,
#  '運営': 833,
#  '過去': 834,
#  '違反': 835,
#  '選び': 836,
#  '選手': 837,
#  '選抜': 838,
#  '選択': 839,
#  '還元': 840,
#  '部員': 841,
#  '部屋': 842,
#  '部長': 843,
#  '部門': 844,
#  '郵便': 845,
#  '都道府県': 846,
#  '配信': 847,
#  '配布': 848,
#  '配送': 849,
#  '重要': 850,
#  '金額': 851,
#  '開催': 852,
#  '開始': 853,
#  '開成': 854,
#  '開発': 855,
#  '開設': 856,
#  '開講': 857,
#  '関係': 858,
#  '関連': 859,
#  '閲覧': 860,
#  '附属': 861,
#  '限定': 862,
#  '随時': 863,
#  '障害': 864,
#  '雑誌': 865,
#  '電気': 866,
#  '電話': 867,
#  '項目': 868,
#  '領域': 869,
#  '願書': 870,
#  '食事': 871,
#  '食堂': 872,
#  '高校': 873,
#  '高等': 874,
#  '（株）': 875,
#  '）.': 876,
#  '）;': 877}

# %% [markdown]
# ## 以下試行錯誤

# %%
ut_df = pd.DataFrame(ut_texts)
ut_df
# Out:
#                0    1     2
# 0             研究  299  None
# 1            ...  166  None
# 2             情報  135  None
# 3             平成  113  None
# 4             年度  104  None
# 5             大学  103  None
# 6           2018   95  None
# 7          キャンパス   89  None
# 8             教育   86  None
# 9             こと   69  None
# 10            03   67  None
# 11            社会   64  None
# 12            学生   57  None
# 13            30   57  None
# 14            利用   56  None
# 15            00   55  None
# 16            学部   52  None
# 17            10   51  None
# 18            ため   50  None
# 19            駒場   48  None
# 20            12   45  None
# 21          センター   45  None
# 22            日本   44  None
# 23            活動   44  None
# 24            医療   43  None
# 25            東京   43  None
# 26           こちら   43  None
# 27           サイト   43  None
# 28            紹介   43  None
# 29           PDF   42  None
# ...          ...  ...   ...
# 3413   Tricoteur    1  None
# 3414         ライト    1  None
# 3415          97    1  None
# 3416          依頼    1  None
# 3417        1301    1  None
# 3418     College    1  None
# 3419          主役    1  None
# 3420          英文    1  None
# 3421          斬新    1  None
# 3422         URA    1  None
# 3423          新年    1  None
# 3424        7579    1  None
# 3425        3705    1  None
# 3426        6700    1  None
# 3427          ケガ    1  None
# 3428         562    1  None
# 3429          伊吹    1  None
# 3430          平和    1  None
# 3431          Ng    1  None
# 3432         芥川賞    1  None
# 3433        そのもの    1  None
# 3434  ツイッターアカウント    1  None
# 3435          信号    1  None
# 3436         ニュー    1  None
# 3437          季節    1  None
# 3438       xauto    1  None
# 3439    uploaded    1  None
# 3440   スーパーローテート    1  None
# 3441          有限    1  None
# 3442          Zj    1  None
#
# [3443 rows x 3 columns]

# %%
ut_texts = []
with open('./mayfes/text_data/todai_noun.txt', 'r') as f:
    for line in f:
        ut_texts.append(line[1:-2].replace(' ', '').split(','))
ut_df = pd.DataFrame(ut_texts)
drop_index = ut_df.loc[ut_df[2].notnull(), :].index
ut_df.drop(index=drop_index).dropna(axis=1).reset_index(drop=True)

# %%
drop_index = ut_df.loc[ut_df[2].notnull(), :].index

# %%
ut_df.drop(index=drop_index).dropna(axis=1).reset_index(drop=True)
# Out:
#                0    1
# 0             研究  299
# 1            ...  166
# 2             情報  135
# 3             平成  113
# 4             年度  104
# 5             大学  103
# 6           2018   95
# 7          キャンパス   89
# 8             教育   86
# 9             こと   69
# 10            03   67
# 11            社会   64
# 12            学生   57
# 13            30   57
# 14            利用   56
# 15            00   55
# 16            学部   52
# 17            10   51
# 18            ため   50
# 19            駒場   48
# 20            12   45
# 21          センター   45
# 22            日本   44
# 23            活動   44
# 24            医療   43
# 25            東京   43
# 26           こちら   43
# 27           サイト   43
# 28            紹介   43
# 29           PDF   42
# ...          ...  ...
# 3404   Tricoteur    1
# 3405         ライト    1
# 3406          97    1
# 3407          依頼    1
# 3408        1301    1
# 3409     College    1
# 3410          主役    1
# 3411          英文    1
# 3412          斬新    1
# 3413         URA    1
# 3414          新年    1
# 3415        7579    1
# 3416        3705    1
# 3417        6700    1
# 3418          ケガ    1
# 3419         562    1
# 3420          伊吹    1
# 3421          平和    1
# 3422          Ng    1
# 3423         芥川賞    1
# 3424        そのもの    1
# 3425  ツイッターアカウント    1
# 3426          信号    1
# 3427         ニュー    1
# 3428          季節    1
# 3429       xauto    1
# 3430    uploaded    1
# 3431   スーパーローテート    1
# 3432          有限    1
# 3433          Zj    1
#
# [3434 rows x 2 columns]
